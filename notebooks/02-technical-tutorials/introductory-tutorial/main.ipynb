# %% [markdown]
# # Introductory atoti Tutorial
# This notebook can be found in our public GitHub repository here:
# [introductory-tutorial](https://github.com/atoti/notebooks/tree/main/notebooks/02-technical-tutorials/introductory-tutorial)
#
# and viewable in the notebook viewer here:
# [introductory-tutorial-notebook](https://nbviewer.org/github/atoti/notebooks/tree/main/notebooks/02-technical-tutorials/introductory-tutorial/main.ipynb)

# %% [markdown]
# ## Overview
#
# We will be exploring how to use **atoti**.
# Our main focus will be on cube creation and the various ways one can slice and dice sales data.
#
# We will use simple sales data comprising of orders, customers, products and employees in order to show how simple it is to create a basic cube from this data, and how to further embellish it to meet our BI (Business Intelligence) needs.
#
# **Customers** order amounts of **Products** from **Employees**
#
# These **Orders** are what we will work with.
#
# ### This tutorial will cover the following:
# * What is atoti
# * Getting started with atoti
# * Loading data
# * Joining tables
# * Visualizing the cube
# * Manipulating hierarchies and levels
# * Creating new measures
# * Aggregating and using vectors
# * Lookup measures
# * Simulations / What-ifs
# * Querying the cube
# * Creating a Dashboard
# * Further Reading
#
# Note that the material in this tutorial is also available in our more comprehensive Java and Python API courses, available on request.

# %% [markdown]
# ## What is atoti?

# %% [markdown]
# <div style="text-align: center;"><a href="https://www.atoti.io/?utm_source=gallery&utm_content=bike-sales" target="_blank" rel="noopener noreferrer"><img src="https://data.atoti.io/notebooks/bike-sales/atoti-definition.PNG" alt="Try atoti"></a></div>

# %% [markdown]
# **atoti** can load data from various sources into an in-memory database from which a multi-dimensional cube can be built.
#
# The workflow into an ActivePivot cube server can be viewed as follows.
#
# ![image.png](attachment:b1de8d50-1719-4205-9b6d-816c40a78dbc.png)
#
# * An internal database is created to model and store the input data
#
# * Source data can be loaded from a number of different sources
#
# * Once data is loaded, the data is aggregated and a cube is created
#
# * Additional measures can be created based off these raw aggregated numbers to allow for
#     * currency conversions
#     * non-linear aggregations
#     * more complex calculations based off existing data
#
# * Visualization can be done in ActiveViam's ActiveUI, or even Excel and other BI tools
#
# This allows the user to slice and dice the data in any way.
#
# We will see this in action when we visualize the cube.
#
# See [atoti](https://www.atoti.io) for guides, a tutorial, articles, videos and a set of example notebooks.

# %% [markdown]
# **atoti** is the free community edition, whereas **Atoti+** is the enterprise version.
#
# Both could be productionized but **atoti** is subjected to [EULA](https://docs.atoti.io/latest/eula.html) that limits the number of users who could use the application.
#
# And of course, atoti is not meant for commercial use.
#
# The **atoti** Jupyter lab extension allows data scientists and business users to analyse data and create metrics/measures on the fly and on their own desktops.
#
# ![image.png](attachment:49d7a032-d3b5-433e-910b-830a1fe69bdc.png)
#
# Once new measures have been created that meet the business needs, they may be incorporated into a deployed server environment by the IT dev team.
#
# **atoti** is the desktop python environment that allows data scientists to analyise their data and formulate new measures as required.
#
# **Atoti+** is the server deployment API, implemented in either Java or Python as a fully-fledged project. Such a server can form a production system that is separate to the desktop Jupyter lab environment.
#
# There is a **Atoti+** package available within Jupyter which isn't available with the community edition of **atoti**.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Refer to [atoti's tutorial](https://docs.atoti.io/latest/getting_started/tutorial/tutorial.html#Getting-started) for more examples on how to get started.
# Or check out the other notebooks in our [notebook gallery](https://github.com/atoti/notebooks/tree/main/notebooks).

# %% [markdown]
# ### Quick [Installation](https://docs.atoti.io/latest/getting_started/installation.html) Guide

# %% [markdown]
# Install the [Anaconda 64-bit](https://docs.anaconda.com/anaconda/install) python package manager.
#
# And run the following:
#
# * conda config --add channels conda-forge
# * conda config --add channels https://conda.atoti.io
# * conda create --name atoti
# * conda activate atoti
# * conda install atoti atoti-jupyterlab python
#
# And start your Jupyter kernel in a shell:
#
# * jupyter lab
#
# This will also open a browser with which you can open any notebook files (.ipynb).

# %% [markdown]
# ### Running your notebook

# %% [markdown]
# We'll be completing this exploration of sales order data using the atoti library and a little bit of pandas (for dataframes).
# For this, we first need to import the two libraries...

# %%
import atoti as tt
import pandas as pd

# %% [markdown]
# We now need create an atoti session.
# We want to create this session with two specific bits of configuration:
# * one to specify that we want to persist UI dashboards etc in an H2 file-based database
# * the other to specify the port number of the atoti cube server
#
# Both of these are optional.
# For this notebook, we want to be able to save our dashboards so we can use them each time we spin up the cube server.
#
# We also want to use the same port number to access the UI each time.
#
# Let's create the atoti session using this configuration...

# %%
session = tt.Session(
    user_content_storage="./content",
    port=9090,
)

# %% [markdown]
# This has actually launched a Java Virtual Machine (JVM) running an empty cube in the background (it will take a few seconds to start).
#
# It is this cube server that we will be loading data into and manipulating hierarchies and measures.
#
# If you wish to see the server log, you can locate it by running the following command...

# %%
session.logs_path
# Out:
# WindowsPath('C:/Users/hfy/.atoti/1676880946_8ZCCBR/logs/server.log')

# %% [markdown]
# ## Loading data

# %% [markdown]
# At the heart of every **atoti** server is an in-memory database.
#
# This database is then used to construct the cube, its hierarchies and aggregated measures.

# %% [markdown]
# We have some sales order data in a CSV file, so let's load this data into the **atoti** database...

# %%
orders = session.read_csv(
    "data/Orders.csv",
    keys=["OrderId"],
    table_name="Orders",
    types={"OrderDate": tt.type.LOCAL_DATE},
    date_patterns={"OrderDate": "DD/mm/yyyy"},
)

# %% [markdown]
# Note that for the OrderDate column, we want the data to be parsed as LocalDate objects and not as Strings.
#
# When overriding the default column types, we specify the "types" mapping.
#
# Where a pattern is required, then we also need to specify the "date_patterns" attribute.
#
# Let's see what has been loaded...

# %%
orders.head(100)
# Out:
#          OrderDate  QuantitySold  SellingPricePerUnit       ShipperName  \
# OrderId
# 19      2019-01-18           971                11.10    Freight United
# 39      2019-01-18           120               284.01    Speedy Express
# 59      2019-01-18           230                 6.89  Federal Shipping
# 79      2019-01-18           913                11.67   The Transporter
# 99      2019-01-18           867                14.73  Federal Shipping
# ...            ...           ...                  ...               ...
# 303     2019-01-15           505                 9.39    Speedy Express
# 323     2019-01-15           499                 6.97    Freight United
# 343     2019-01-15           427                 6.62  Federal Shipping
# 363     2019-01-15           224                20.69    Freight United
# 383     2019-01-15           877                20.48  Federal Shipping
#
#          ProductId  EmployeeId CustomerId
# OrderId
# 19             708       18422      c1891
# 39            1410       18508      c3179
# 59             604       98635       c883
# 79            1124       18680      c4467
# 99            1020       18336      c3627
# ...            ...         ...        ...
# 303            604       63528      c5419
# 323           1488       18680      c4467
# 343           1241       98635      c4467
# 363           1332       12344      c5811
# 383            825       18465      c5083
#
# [100 rows x 7 columns]

# %% [markdown]
# Now let's load some reference data for Customers, Products and Employees into their own tables...

# %%
products = session.read_csv(
    "data/Products.csv",
    table_name="Products",
    keys=["ProductId"],
    separator=",",
    encoding="iso-8859-1",
)

# %% [markdown]
# Note the use of the "encoding" parameter because this file contains characters that aren't standard ASCII.

# %%
products.head(20)
# Out:
#                                ProductName ProductCategory  \
# ProductId
# 773                                  Chang       Beverages
# 1033                          Lakkalikööri       Beverages
# 1293             Wimmers gute Semmelknödel  Grains/Cereals
# 786                                Pavlova     Confections
# 1046               Thüringer Rostbratwurst    Meat/Poultry
# 1306                      Carnarvon Tigers         Seafood
# 539                         Queso Cabrales  Dairy Products
# 799                            Inlagd Sill         Seafood
# 1059                           Ipoh Coffee       Beverages
# 1319                      Gudbrandsdalsost  Dairy Products
# 552          Singaporean Hokkien Fried Mee  Grains/Cereals
# 812                   Raclette Courdavault  Dairy Products
# 1072                                 Ikura         Seafood
# 1332             Louisiana Hot Spiced Okra      Condiments
# 565                 Mozzarella di Giovanni  Dairy Products
# 825                          Perth Pasties    Meat/Poultry
# 1085                           Flotemysost  Dairy Products
# 1345           Chef Antons Cajun Seasoning      Condiments
# 578                                   Tofu         Produce
# 838        Original Frankfurter grüne Soße      Condiments
#
#                                     Supplier  PurchasingPricePerUnit
# ProductId
# 773                           Exotic Liquids                   10.26
# 1033                               Karkki Oy                    9.72
# 1293       Plutzer Lebensmittelgroßmärkte AG                   21.55
# 786                            Pavlova, Ltd.                    9.39
# 1046       Plutzer Lebensmittelgroßmärkte AG                   75.74
# 1306                           Pavlova, Ltd.                   36.00
# 539         Cooperativa de Quesos Las Cabras                   11.34
# 799                        Svensk Sjöföda AB                   10.26
# 1059                            Leka Trading                   31.05
# 1319                         Norske Meierier                   23.33
# 552                             Leka Trading                    8.06
# 812                             Gai pâturage                   29.70
# 1072                           Tokyo Traders                   17.86
# 1332              New Orleans Cajun Delights                   10.40
# 565                  Formaggi Fortini s.r.l.                   18.77
# 825                               Gday, Mate                   18.86
# 1085                         Norske Meierier                   12.38
# 1345              New Orleans Cajun Delights                   12.67
# 578                                  Mayumis                   12.56
# 838        Plutzer Lebensmittelgroßmärkte AG                    7.96

# %% [markdown]
# We can check on any loading errors by running the following command...

# %%
products._loading_report.error_messages
# Out:
# []

# %% [markdown]
# Or by checking the server log file in the location provided by the following command...

# %%
session.logs_path
# Out:
# WindowsPath('C:/Users/hfy/.atoti/1676880946_8ZCCBR/logs/server.log')

# %% [markdown]
# Let's now load in the Customers and Employees CSV files...

# %%
customers = session.read_csv(
    "data/Customers.csv",
    keys=["CustomerId"],
    table_name="Customers",
    encoding="iso-8859-1",
)

# %%
customers.head(10)
# Out:
#                                    CompanyName                        Address  \
# CustomerId
# c1891                     GROSELLA-Restaurante      5ª Ave. Los Palos Grandes
# c3011                 Lonesome Pine Restaurant             89 Chiaroscuro Rd.
# c4131                       Eastern Connection                 35 King George
# c5251               Cactus Comidas para llevar                    Cerrito 333
# c1947                     White Clover Markets    305 - 14th Ave. S. Suite 3B
# c3067       Ana Trujillo Emparedados y helados  Avda. de la Constitución 2222
# c4187                  Antonio Moreno Taquería                 Mataderos 2312
# c5307                  Great Lakes Food Market               2732 Baker Blvd.
# c883                 Vins et alcools Chevalier             59 rue de l'Abbaye
# c2003                    Split Rail Beer & Ale                   P.O. Box 555
#
#                     City Region PostalCode    Country           Phone
# CustomerId
# c1891            Caracas     DF       1081  Venezuela    (2) 283-2951
# c3011           Portland     OR      97219        USA  (503) 555-9573
# c4131             London    N/A    WX3 6FW         UK  (171) 555-0297
# c5251       Buenos Aires    N/A       1010  Argentina    (1) 135-5555
# c1947            Seattle     WA      98128        USA  (206) 555-4112
# c3067        México D.F.    N/A       5021     Mexico    (5) 555-4729
# c4187        México D.F.    N/A       5023     Mexico    (5) 555-3932
# c5307             Eugene     OR      97403        USA  (503) 555-7555
# c883               Reims    N/A      51100     France     26.47.15.10
# c2003             Lander     WY      82520        USA  (307) 555-4680

# %%
employees = session.read_csv(
    "data/Employees.csv", keys=["EmployeeId"], table_name="Employees"
)

# %%
employees.head(10)
# Out:
#                 EmployeeName EmployeeZone EmployeeCountry EmployeeCity
# EmployeeId
# 12344             Paul Henry         EMEA              FR        Paris
# 12695         Louis Philippe         EMEA              FR         Lyon
# 18336        Steven Buchanan         EMEA              UK       London
# 18379         Michael Suyama         EMEA              UK       London
# 18422       Margaret Peacock     AMERICAS             USA      Redmond
# 18465               Joan Jet     AMERICAS             USA     Kirkland
# 18508         Anne Dodsworth         EMEA              UK       London
# 18551          Nancy Davolio     AMERICAS             USA      Seattle
# 18594         Laura Callahan     AMERICAS             USA      Seattle
# 18637          Andrew Fuller     AMERICAS             USA       Tacoma

# %% [markdown]
# We will also load in some data associated with the Shippers of the goods.
#
# This data shows the cost per unit to ship goods.
# The more goods shipped, the cheaper the rate per unit is.

# %%
shippers = session.read_csv(
    "data/Shippers.csv", keys=["Shipper", "Interval"], table_name="Shippers"
)

# %%
shippers.head(10)
# Out:
#                                                 Rate
# Shipper          Interval
# Federal Shipping Quantity less than 100        0.630
# Freight United   Quantity less than 100        0.770
# Federal Shipping Quantity between 100 and 300  0.090
#                  Quantity between 300 and 500  0.061
#                  Quantity between 500 and 700  0.017
# The Transporter  Quantity between 500 and 700  0.009
# Federal Shipping Quantity more than 700        0.014
# Freight United   Quantity between 100 and 300  0.039
# Speedy Express   Quantity less than 100        0.980
#                  Quantity between 300 and 500  0.130

# %% [markdown]
# ### Loading Vectors

# %% [markdown]
# In **atoti**, we can also load vectors, or arrays of values.
#
# For this exercise we have a file of historic prices for each product.
#
# Each row will contain a vector of these historic prices per product.

# %%
historicalPrices = session.read_csv(
    "data/HistoricalPrices.csv",
    keys=["ProductId"],
    table_name="HistoricalPrices",
    types={"HistoricalPrice": tt.type.DOUBLE_ARRAY},
)

# %%
historicalPrices.head(10)
# Out:
#                                              HistoricalPrice
# ProductId
# 773        [14.91, 13.95, 7.94, 5.21, 12.09, 8.13, 5.56, ...
# 1033       [10.09, 11.16, 12.32, 11.75, 10.69, 10.98, 12....
# 1293       [22.8, 32.05, 32.01, 30.1, 12.73, 25.96, 13.95...
# 786        [13.5, 5.93, 6.4, 8.54, 6.83, 5.51, 8.55, 12.8...
# 1046       [97.18, 77.33, 84.31, 97.53, 46.15, 65.45, 55....
# 1306       [47.36, 51.61, 18.86, 35.44, 23.77, 26.18, 34....
# 539        [8.06, 11.86, 14.58, 9.28, 7.58, 15.01, 12.06,...
# 799        [13.46, 7.75, 6.99, 13.31, 10.36, 8.6, 14.36, ...
# 1059       [34.4, 42.13, 42.71, 17.34, 20.65, 27.52, 17.3...
# 1319       [13.13, 28.03, 30.22, 31.81, 12.28, 31.43, 21....

# %% [markdown]
# Why use vectors?
#
# Vectors in **atoti** are natively aggregated.
#
# They can save heap memory by only requiring **one** record instead of one record per vector element.
#
# The above vectors represent the historical prices of a product for the last 250 days.
#
# If we were to **not** use vectors, we would need to have one record per date per product, thus 250 records in the table instead of 1.
#
# Not only would this require more memory, it would also contribute many more cube locations, using even more heap memory, and slowing down access through queries.
#
# We will look at how we can use these vector aggregations when we discuss creating measures.

# %% [markdown]
# We can further configure the loading of CSV files as described here:
# [Session read_csv](https://docs.atoti.io/latest/lib/atoti/atoti.session.html#atoti.Session.read_csv)

# %% [markdown]
# ## Joining tables in the database
#
# Now we have loaded our data into different tables (or stores), we need to define the relationships between them.

# %% [markdown]
# Generally, the database will follow a Star schema with the largest store the "base" store.
# This store contains the data at the lowest level of granularity, known as the "facts" for the cube.
# In this project, the Orders table is the base store.
#
# ![image.png](attachment:926e91b9-8766-44fe-9dc1-319feb3e2fbf.png)

# %% [markdown]
# We can extend this further into a Snowflake Schema where referenced tables can reference further tables...

# %% [markdown]
# ![image.png](attachment:9a334dc2-4ef9-4798-98aa-5ae511ce0344.png)

# %% [markdown]
# Let's join our main Orders table with the Products table...

# %%
orders.join(products, orders["ProductId"] == products["ProductId"])

# %% [markdown]
# We now want to join the Orders table with the Customers table...

# %%
orders.join(customers, orders["CustomerId"] == customers["CustomerId"])

# %% [markdown]
# Now join the Orders table with the Employees table...

# %%
orders.join(employees, orders["EmployeeId"] == employees["EmployeeId"])

# %% [markdown]
# And the historical prices with the Products table...

# %%
products.join(historicalPrices, products["ProductId"] == historicalPrices["ProductId"])

# %% [markdown]
# We can now see the relationships between the tables...

# %%
session.tables.schema

# %% [markdown]
# We can see that **atoti** has inferred the data types for each column based on the data in the CSV files, unless we have explicitly specified the types (as with the OrderDate column in the Orders table)
#
# Note that we have an "isolated" table called "Shippers".
#
# We will use this as a lookup table in order to determine the cost of transporting the goods for each order based on the number of goods sent.

# %% [markdown]
# ## Lookup tables

# %% [markdown]
# Earlier, we loaded the Shippers table.
#
# It's key fields are "Shipper" and "Interval".
#
# The cost of shipping the goods depends on the quantity sold.
#
# The higher the quantity, the cheaper it is to transport the goods.
#
# This is what the data looks like:
#
# ![image.png](attachment:4a237fa9-c67c-4bf9-aa85-55a38043a3a6.png)

# %% [markdown]
# We know that the Orders table contains a "ShipperName" field, and we know there is a field called QuantitySold.
#
# In order to determine how much it costs to ship a particular order we need to compare the QuantitySold value with the "Interval", a bucketing of differing quantities sold.
#
# We can "partially" join this table to the Orders table in the following way...

# %%
orders.join(shippers, orders["ShipperName"] == shippers["Shipper"])

# %% [markdown]
# This has now created an "analysis hierarchy" in the cube called Shippers with which we can look up the relevant transport rate according to the quantity sold for an order.
#
# It's not properly joined with the Orders table, so represents a many-to-many join.
#
# One Order row cannot be joined to only one Shippers row because of this extra "Interval" key field on the Shippers table.
#
# You can now see in the schema that the join is represented with a dotted line...

# %%
session.tables.schema

# %% [markdown]
# We'll see how we can use this new type of hierarchy a little later when we discuss lookup measures.

# %% [markdown]
# ## Visualizing the cube
#
# When we create a cube, atoti will use the columns from the joined tables to create levels in cube hierarchies automatically.
#
# We need to specify the "base" store from which the cube will use to do this.
#
# For a record to be reachable in the cube, it must exist in the base store.
#
# Here we will be using the **auto** mode where we let **atoti** create hierarchies and measures for us.
#
# The measures are only created from the base store.
#
# This is the default mode, but this can be changed for different behaviour:
#
# * auto: Creates hierarchies for every key column or non-numeric column of the table, and measures for every numeric column.
#
# * manual: Does not create any hierarchy or measure (except for the count).
#
# * no_measures: Creates the hierarchies like auto but does not create any measures.
#
# See [create_cube](https://docs.atoti.io/latest/lib/atoti/atoti.session.html#atoti.Session.create_cube) for more details.
#
# Let's create the cube and see what's been done for us.

# %%
cube = session.create_cube(orders, "OrdersCube")

# %% [markdown]
# You will notice that there is an **atoti** Jupyter notebook extension allowing the creation of pivot tables, charts etc.
#
# By default, it will show a pivot table when you visualize the cube.
#
# You can see the list of auto-generated measures and hierarchies.
#
# ![image.png](attachment:41fd5cba-0d6c-42e1-846c-a00d9ec71be6.png)

# %% [markdown]
# We can now visualize this cube within this notebook by creating a pivot table.
#
# After running the visualize command, a pivot table will be created.
# Click in this table and on the "a." **atoti** UI plugin in the left-side drawer to visualize the cube.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# **atoti** has automatically created the following for us:
#
# * Aggregated measures .SUM and .MEAN for all numerical fields
#
# * Single-level hierarchies based off all other non-numerical fields
#
# We can see that atoti has created the following hierarchies, based on the non-numeric data loaded

# %%
hierarchies = cube.hierarchies

# %%
hierarchies
# Out:
# {('Products', 'Supplier'): <atoti.hierarchy.Hierarchy object at 0x0000015567CA0880>, ('Orders', 'OrderDate'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9A460>, ('Products', 'ProductName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9A5B0>, ('Customers', 'Phone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9A640>, ('Customers', 'Address'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9A8B0>, ('Customers', 'Region'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9AB50>, ('Employees', 'EmployeeCountry'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9AE80>, ('Products', 'ProductCategory'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9AFD0>, ('Customers', 'PostalCode'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9EFA0>, ('Orders', 'CustomerId'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9EDC0>, ('Employees', 'EmployeeCity'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9EAF0>, ('Customers', 'Country'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9EB50>, ('Shippers', 'Interval'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9EB20>, ('Orders', 'OrderId'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9E8B0>, ('Customers', 'CompanyName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9E430>, ('Orders', 'ShipperName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9E340>, ('Employees', 'EmployeeName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9E2B0>, ('Employees', 'EmployeeZone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C9E7F0>, ('Customers', 'City'): <atoti.hierarchy.Hierarchy object at 0x0000015567B70E50>}

# %% [markdown]
# It has also created default "measures" based on aggregations of numeric data.

# %%
measures = cube.measures

# %%
list(measures)
# Out:
# ['contributors.COUNT',
#  'update.TIMESTAMP',
#  'SellingPricePerUnit.MEAN',
#  'SellingPricePerUnit.SUM',
#  'QuantitySold.MEAN',
#  'QuantitySold.SUM',
#  'ProductId.MEAN',
#  'ProductId.SUM',
#  'EmployeeId.MEAN',
#  'EmployeeId.SUM']

# %% [markdown]
# We will look at how we can override the default list of hierarchies and measures in the following sections.

# %% [markdown]
# ## Manipulating hierarchies and levels

# %% [markdown]
# See the [atoti hierarchies](https://docs.atoti.io/latest/lib/atoti/atoti.hierarchies.html#atoti.hierarchies.Hierarchies) package for a full list of features.

# %% [markdown]
# ### Removing Hierarchies

# %% [markdown]
# The automatically-generated list of hierarchies contains some ID hierarchies that we don't necessarily want to keep.
#
# ![image.png](attachment:3267d936-2774-4e56-886e-6a1768f4b5d7.png)
#
# Let's look at how we can remove these.

# %% [markdown]
# We already have the hierarchies when we executed the following line.

# %%
hierarchies = cube.hierarchies

# %% [markdown]
# We can now delete the hierarchies we don't want to keep like this...

# %%
del hierarchies["CustomerId"]

# %% [markdown]
# And we can now see that the CustomerId hierarchy has been removed.

# %%
hierarchies
# Out:
# {('Products', 'Supplier'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2FA0>, ('Orders', 'OrderDate'): <atoti.hierarchy.Hierarchy object at 0x0000015567C65640>, ('Products', 'ProductName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C13E50>, ('Customers', 'Phone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C13AF0>, ('Customers', 'Address'): <atoti.hierarchy.Hierarchy object at 0x0000015567C13FA0>, ('Customers', 'Region'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54BE0>, ('Employees', 'EmployeeCountry'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54A60>, ('Products', 'ProductCategory'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54AF0>, ('Customers', 'PostalCode'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54790>, ('Employees', 'EmployeeCity'): <atoti.hierarchy.Hierarchy object at 0x0000015567C544C0>, ('Customers', 'Country'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54520>, ('Shippers', 'Interval'): <atoti.hierarchy.Hierarchy object at 0x0000015567C544F0>, ('Orders', 'OrderId'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54280>, ('Customers', 'CompanyName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C540A0>, ('Orders', 'ShipperName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54CA0>, ('Employees', 'EmployeeName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54D60>, ('Employees', 'EmployeeZone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54E20>, ('Customers', 'City'): <atoti.hierarchy.Hierarchy object at 0x0000015567C54EE0>}

# %% [markdown]
# We can also see this when we visualize the cube...
#
# ![image.png](attachment:4f6cb80b-a77f-4f23-a158-299e8c3741e7.png)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ### Creating Multi-Level Hierarchies

# %% [markdown]
# You would have noticed that there are two hierarchies called "ProductCategory" and "ProductName".
#
# ![image.png](attachment:8a4eeb9c-e838-4a56-8d78-be8df85d619c.png)
#
# At the moment they are visualized as two separate hierarchies, but it would make sense to have these as two levels of the **same** hierarchy.
#
# This would allow us to first view the different product categories, and then drill down into the product names for each category.
#
# We can restructure this into a new "Products" hierarchy as follows.

# %% [markdown]
# We can obtain the list of levels from the cube in order to create the new hierarchy

# %%
levels = cube.levels

# %%
hierarchies["Products"] = {
    "ProductCategory": levels["ProductCategory"],
    "ProductName": levels["ProductName"],
}

# %% [markdown]
# We now have the "Products" multi-level hierarchy and the previous single-level hierarchies.
#
# ![image.png](attachment:4f41518b-25d7-435e-b03e-84f6b7e02afb.png)
#
# We can now remove the original single-level hierarchies "ProductCategory" and "ProductName"...

# %%
hierarchies
# Out:
# {('Products', 'Supplier'): <atoti.hierarchy.Hierarchy object at 0x0000015567C43A60>, ('Orders', 'OrderDate'): <atoti.hierarchy.Hierarchy object at 0x0000015567C455B0>, ('Products', 'ProductName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C45640>, ('Customers', 'Phone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C45670>, ('Customers', 'Address'): <atoti.hierarchy.Hierarchy object at 0x0000015567C455E0>, ('Products', 'Products'): <atoti.hierarchy.Hierarchy object at 0x0000015567C45A60>, ('Customers', 'Region'): <atoti.hierarchy.Hierarchy object at 0x0000015567C34340>, ('Employees', 'EmployeeCountry'): <atoti.hierarchy.Hierarchy object at 0x0000015567C34790>, ('Products', 'ProductCategory'): <atoti.hierarchy.Hierarchy object at 0x0000015567C34C10>, ('Customers', 'PostalCode'): <atoti.hierarchy.Hierarchy object at 0x0000015567C345B0>, ('Employees', 'EmployeeCity'): <atoti.hierarchy.Hierarchy object at 0x0000015567C34A00>, ('Customers', 'Country'): <atoti.hierarchy.Hierarchy object at 0x0000015567C349D0>, ('Shippers', 'Interval'): <atoti.hierarchy.Hierarchy object at 0x0000015567C34640>, ('Orders', 'OrderId'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5CE20>, ('Customers', 'CompanyName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5C580>, ('Orders', 'ShipperName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5C190>, ('Employees', 'EmployeeName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5C310>, ('Employees', 'EmployeeZone'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5C1F0>, ('Customers', 'City'): <atoti.hierarchy.Hierarchy object at 0x0000015567C5C9D0>}

# %% [markdown]
# Again, we can visualize this...

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
del hierarchies["ProductCategory"]
del hierarchies["ProductName"]

# %% [markdown]
# We can see that these hierarchies have been removed...
#
# ![image.png](attachment:a1679617-a7b8-46cb-a6ca-8552fe4f30de.png)

# %%
hierarchies
# Out:
# {('Products', 'Supplier'): <atoti.hierarchy.Hierarchy object at 0x0000015567C89E50>, ('Orders', 'OrderDate'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB27F0>, ('Customers', 'Phone'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2B20>, ('Customers', 'Address'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2D90>, ('Products', 'Products'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2F70>, ('Customers', 'Region'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2EB0>, ('Employees', 'EmployeeCountry'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2F10>, ('Customers', 'PostalCode'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2970>, ('Employees', 'EmployeeCity'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2520>, ('Customers', 'Country'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2DF0>, ('Shippers', 'Interval'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2BB0>, ('Orders', 'OrderId'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB25E0>, ('Customers', 'CompanyName'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2A30>, ('Orders', 'ShipperName'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2460>, ('Employees', 'EmployeeName'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2D30>, ('Employees', 'EmployeeZone'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB22E0>, ('Customers', 'City'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2370>}

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# We would probably want to do the same for the Employee-related hierarchies, creating a multi-level hierarchy with the following structure.
#
# **EmployeesGeography** hierarchy
# * EmployeeZone level
# * EmployeeCountry level
# * EmployeeCity level

# %%
hierarchies["EmployeesGeography"] = {
    "EmployeeZone": levels["EmployeeZone"],
    "EmployeeCountry": levels["EmployeeCountry"],
    "EmployeeCity": levels["EmployeeCity"],
}

# %%
del hierarchies["EmployeeZone"]
del hierarchies["EmployeeCountry"]
del hierarchies["EmployeeCity"]

# %%
hierarchies
# Out:
# {('Products', 'Supplier'): <atoti.hierarchy.Hierarchy object at 0x0000015567CCB2B0>, ('Orders', 'OrderDate'): <atoti.hierarchy.Hierarchy object at 0x0000015567C21A30>, ('Customers', 'Phone'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAAAF0>, ('Customers', 'Address'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAABE0>, ('Products', 'Products'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAA970>, ('Customers', 'Region'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAA5E0>, ('Customers', 'PostalCode'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAAC40>, ('Customers', 'Country'): <atoti.hierarchy.Hierarchy object at 0x0000015567CAACA0>, ('Shippers', 'Interval'): <atoti.hierarchy.Hierarchy object at 0x0000015567B70B80>, ('Orders', 'OrderId'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB28E0>, ('Customers', 'CompanyName'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2F40>, ('Orders', 'ShipperName'): <atoti.hierarchy.Hierarchy object at 0x0000015567CB2B20>, ('Employees', 'EmployeeName'): <atoti.hierarchy.Hierarchy object at 0x0000015567C1BDF0>, ('Customers', 'City'): <atoti.hierarchy.Hierarchy object at 0x0000015567C1BE20>, ('Employees', 'EmployeesGeography'): <atoti.hierarchy.Hierarchy object at 0x0000015567C1B280>}

# %% [markdown]
# We can now see this EmployeesGeography multi-level hierarchy when we visualize the cube:
#
# ![image.png](attachment:e18269be-9991-4fef-89e6-6aba4d844959.png)

# %%
session.visualize("Employees Multi Hierarchy")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# One other typical use-case for multi-level hierarchies is with dates.
#
# We may wish to bucket dates firstly into YEARS, then QUARTERS, then MONTHS, and then the actual date.
#
# This will allow us to see measures across years, but then give us the ability to drilldown further into quarters of particular years.
#
# We can do this with date columns by using the [create_date_hierarchy](https://docs.atoti.io/latest/lib/atoti/atoti.cube.html#atoti.Cube.create_date_hierarchy) method on a cube...

# %%
cube.create_date_hierarchy(
    "YQM",  # the new hierarchy name
    column=orders["OrderDate"],  # the table column containing date data
    levels={
        "Year": "yyyy",  # this defines the level and the part of the column's LocalDate object to take as a value
        "Quarter": "QQQ",
        "Month": "MMM",
    },
)

# %% [markdown]
# We now have a new YQM multi-level hierarchy where we can drilldown into the different buckets, or view data at different levels.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ## Creating Measures

# %% [markdown]
# See the [atoti,measure](https://docs.atoti.io/latest/lib/atoti/atoti.measure.html) and [atoti.agg](https://docs.atoti.io/latest/lib/atoti/atoti.agg.html) packages for a full list of features.

# %% [markdown]
# So far, the cube is created using the default set of measures using SUM and MEAN on the numerical columns.
#
# ![image.png](attachment:9cc0e68d-0cc2-40e9-ac21-3c859d3080a8.png)
#
# Note also that there is a "contributors.COUNT" measure.
#
# This is the number of facts from the base store that contribute to any cell on a pivot table.
#
# If we create a pivot table with only this measure, it will show the total number of facts from this base store.

# %% [markdown]
# ### Removing unwanted measures

# %% [markdown]
# We can remove measures that we are not interested in, say the MEAN measures...

# %%
del measures["QuantitySold.MEAN"]
del measures["SellingPricePerUnit.MEAN"]

# %% [markdown]
# These measures are no longer present:
#
# ![image.png](attachment:535a303a-9c2c-497e-94dd-c4d7a1e1fb7d.png)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ### Dynamic aggregation measures at a specific level

# %% [markdown]
# We can see there are two measures called "QuantitySold.SUM" and "SellingPricePerUnit.SUM".
#
# These are columns that have been aggregated from the base store, Orders.
#
# If we wanted to see the actual sales value for each order, we would need to multiple both of these to obtain a new "Sales" amount measure (a cash value).
#
# We could create such a measure as follows.

# %%
measures["Sales"] = tt.agg.sum(
    measures["QuantitySold.SUM"] * measures["SellingPricePerUnit.SUM"],
    scope=tt.OriginScope(levels["ProductName"]),
)

# %% [markdown]
# We are essentially doing a SUM aggregation by multiplying both of these measures.
#
# But this value only makes sense at a ProductName level, so the aggregation is done at this level by specifying the "scope" of this new measure.
#
# The aggregation is automatically split by ProductName to calculate the measure value, and then summed to the ProductCategory level.
#
# Even if the Products hierarchy is not present in your pivot table, this scoping will still be done.
#
# This is known as dynamic aggregation.
#
# Let's now see this measure in the cube.
#
# ![image.png](attachment:bd8f93de-a6d8-4c38-889c-b5851e254585.png)

# %%
session.visualize("Sales by Product")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# If we look at the two highlighted cells for QuantitySold.SUM and SellingPricePerUnit.SUM, these are at the ProductCategory level, and their multiplication will give the value 31,495,158.29.
#
#
# ![image.png](attachment:641cbe08-547f-464c-b5d1-82b3c12da478.png)
#
# This is clearly wrong because the SellingPricePerUnit only applies for a specific ProductName.
# The SellingPricePerUnit for Louisiana Hot Spiced Okra will be different to that for Vegie-spread.
# Consequently, the calculation must be done per ProductName per ProductCategory, and then aggregated up.

# %% [markdown]
# An altenative way to define this measure is to use the [sum_product](https://docs.atoti.io/latest/lib/atoti/atoti.agg.sum_product.html#atoti.agg.sum_product) aggregation as follows.

# %%
measures["Sales2"] = tt.agg.sum_product(
    measures["QuantitySold.SUM"],
    measures["SellingPricePerUnit.SUM"],
    scope=tt.OriginScope(levels["ProductName"]),
)

# %% [markdown]
# ### Controlling aggregation level visibility

# %% [markdown]
# If we consider the measures "SellingPricePerUnit.SUM" and "QuantitySold.SUM", they only make sense when seen at a ProductName level, not at the ProductCategory level as they apply to specific products.
#
# We can create new measures that limit the visibility of the original measures to the ProductName level, returning null otherwise...

# %%
measures["SellingPricePerUnit"] = tt.where(
    ~levels["ProductName"].isnull(), measures["SellingPricePerUnit.SUM"]
)

measures["QuantitySold"] = tt.where(
    ~levels["ProductName"].isnull(), measures["QuantitySold.SUM"]
)

# %% [markdown]
# We can see how these versions of these measures return nothing at the ProductCategory level, whereas the original measures do...

# %%
session.visualize("Measure Visibility")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ### Date shifting and trend measures

# %% [markdown]
# We may want to compare measure values across a time/date hierarchy to see the differences on a daily basis.
#
# This essentially shows a trend across a timeline.
#
# We have the "OrderDate" hierarchy, so let's look at creating a Sales Trend measure where we can see the day-to-day differences in Sales.
#
# Firstly, we need the previous day's value of "Sales".
# Here we are shifting the OrderDate hierarchy and taking the value of the Sales measure.
#
# By default, the shift is done by 1 member, although it is possible to shift by more.
# Here we are using -1 to get the previous member.
#
# The natural ordering of dates will be in reverse order, so by getting the previous value will get the date from "yesterday" in effect.

# %%
previousSales = tt.shift(measures["Sales"], hierarchies["OrderDate"], offset=-1)

# %% [markdown]
# We can then compare this previous value with the current value and compute the difference...

# %%
measures["TrendSales"] = tt.where(
    ~previousSales.isnull(), measures["Sales"] - previousSales
)

# %% [markdown]
# Note that we use "where" here because the oldest date won't have a previous value, so we need to check for nulls.

# %% [markdown]
# We can then chart this against the "OrderDate" hierarchy.
# We can further split this line chart by EmployeeName to monitor the trend in sales for each employee.

# %%
session.visualize("Trend Sales")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ### Cumulative measures and running totals

# %% [markdown]
# We may wish to see running or cumulative measure values.
#
# For example, the total Sales across a date range.
#
# We can do this by creating a new measure with a "CumulativeScope" on a date hierarchy.

# %%
measures["RunningSales"] = tt.agg.sum(
    measures["Sales"], scope=tt.CumulativeScope(level=levels["OrderDate"])
)

# %%
session.visualize("Running Totals")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# The RunningSales is the cummulative amount of Sales over the dates.
#
# By highlighting two Sales cells, it gives us the sum for those cells of 6,163,499.82, which is the RunningSales value at that date...
#
# ![image.png](attachment:9da183fb-ee48-468e-a06c-3b435507b826.png)

# %% [markdown]
# ### Ratio Measures against a Parent value

# %% [markdown]
# We may also wish to see the proportion of Sales for each product in each category.
#
# To do this, we can access the parent value of the ProductName level (the ProductCategory), and compute the ratio for each ProductName against this.
#
# Here we want to get the parent value of Sales on the Products hierarchy, one level up from the ProductName level, the ProductCategory level.
#
# If we specified 2 degrees, it will take the value of the Total across all Products, the AllMember.

# %%
measures["Sales Ratio"] = measures["Sales"] / tt.parent_value(
    measures["Sales"], degrees={hierarchies["Products"]: 1}
)
measures["Sales Ratio"].formatter = "DOUBLE[0.00%]"

# %%
session.visualize("Sales Ratio")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ### Aggregating and using vectors

# %% [markdown]
# A key feature of **atoti** is that can natively aggregate arrays of numbers, or vectors.
#
# This saves memory by only requiring one record for all values instead of one record per value.
#
# Merely aggregating a vector doesn't give us much unless we are able to manipulate these aggregated vectors...
#
# ![image.png](attachment:a60d1448-6d9b-49b8-88f8-5b8ecc5947ac.png)

# %% [markdown]
# Fortunately, **atoti** has a range of vector manipulation methods at our disposal.

# %% [markdown]
# The following measure definition will:
#
# * give the mean average value
# * of the 20 largest values
# * from the aggregated vector

# %%
measures["AverageHistoricalPriceOfLargest20"] = tt.array.mean(
    tt.array.n_greatest(
        tt.agg.sum(
            tt.agg.single_value(historicalPrices["HistoricalPrice"]),
            scope=tt.OriginScope(levels["ProductName"]),
        ),
        n=20,
    )
)

# %%
session.visualize("Average of Historical Prices")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# We could also use a quantile to get the 95th lowest price from the whole aggregated vector in the following way...

# %%
measures["LowestHistoricalPriceAt95"] = tt.array.quantile(
    tt.agg.sum(
        tt.agg.single_value(historicalPrices["HistoricalPrice"]),
        scope=tt.OriginScope(levels["ProductName"]),
    ),
    q=0.95,
)

# %%
session.visualize("Lowest Historical Price")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# This is a unique and key feature of **atoti** and allows for **non-linear** aggregations to be made.
#
# In the finance world, Value-At-Risk is one such measure that works off vectors of historical or theoretical profit and loss values.
#
# P&L vectors are aggregated up to the appropriate level in a pivot table, then sorted from least to best, and then a percentile of this sorted vector is taken to represent the VaR.
#
# This quantile is the percentage confidence level that such a loss could happen again.
#
# When used with historical P&L values per day, it reflects the worst loss that can be made based on what has previously happened over, say, the last 1000/2000 days.
#
# You can see this is action in the [ValueAtRisk](https://github.com/atoti/notebooks/tree/main/notebooks/01-use-cases/finance/risk-management/market-risk/value-at-risk) notebook.

# %% [markdown]
# The **atoti** array package can be explored here:
# [array_handling](https://docs.atoti.io/latest/lib/atoti/atoti.array.html)

# %% [markdown]
# ### Lookup measures

# %% [markdown]
# We saw earlier how we created a **many-to-many** join between Orders and Shippers.
#
# This created a special kind of hierarchy called an **analysis hierarchy** which can only be used by specific measures that **know** about this.
#
# What we want to do is return the transport rate for each order depending on the quantity sold, and then return the cost of transporting these goods.

# %%
cube.schema

# %% [markdown]
# Based on the quantity sold, let's use the `where` function to map it to the corresponding shipment "interval"...

# %%
quantitySold = measures["QuantitySold.SUM"]

measures["interval"] = tt.where(
    (~levels["OrderId"].isnull()),
    tt.where(
        {
            (quantitySold > 0) & (quantitySold < 100): "Quantity less than 100",
            (quantitySold >= 100)
            & (quantitySold < 300): "Quantity between 100 and 300",
            (quantitySold >= 300)
            & (quantitySold < 500): "Quantity between 300 and 500",
            (quantitySold >= 500)
            & (quantitySold < 700): "Quantity between 500 and 700",
            quantitySold >= 700: "Quantity more than 700",
        },
        default="Unknown",
    ),
)

# %% [markdown]
# In essense, we have created an interval measure that is conditional on the quantity sold value to determine what the actual "Interval" is.
#
# We can then look up the relevant rate accordingly...

# %%
measures["TransportRate"] = tt.lookup(
    shippers["Rate"],
    (shippers["Interval"] == measures["interval"])
    & (shippers["Shipper"] == levels["ShipperName"]),
)

# %% [markdown]
# Notice that we are looking up the shippers table for the Rate column value where the Shipper column value is the same as
# the current member of the ShipperName hierarchy level and the Interval column value is the same the current value of the Interval measure.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# And finally, we can create a measure that uses this rate and the quantity sold to give the cost of shipping this order...

# %%
measures["TransportCost"] = tt.agg.sum_product(
    measures["TransportRate"],
    measures["QuantitySold.SUM"],
    scope=tt.OriginScope(levels["ShipperName"], levels["OrderId"]),
)

# %% [markdown]
# We can now see how much each order cost to transport...

# %%
session.visualize("Transport Costs")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# Such a lookup is typical in many use-cases, especially where a currency conversion is required to convert to a base currency.
#
# If the orders were all in different currencies, then we cannot aggregate the Sales amounts because Yen amounts cannot be aggregated with USD amounts.
#
# In such an example, we would need to specify the currency on each order row and link to a currency FX table in order to convert to the base currency.
#
# You can see currency conversion notebook example here:  [currency conversion notebook](https://github.com/atoti/notebooks/tree/main/notebooks/02-technical-tutorials/currency-conv-with-weighted-ave)

# %% [markdown]
# ## Simulations / What-ifs

# %% [markdown]
# ### Source Simulations

# %% [markdown]
# Source simulations allow us to create and compare different **scenarios**, and enable **what-if** analysis.
#
# Each scenario can be thought of as a separate versions of your data. We can make updates to the data in a particular scenario independently from the others.
#
# Any measures you have defined can be calculated separately for every scenario, and, because the scenarios are exposed as a hierarchy in the cube, we can compare the results of these measures between scenarios.
#
# Let's start by creating a scenario that for now will mirror our existing "base" data...

# %%
session.create_scenario("Price Simulation")

# %%
session.scenarios
# Out:
# ['Base', 'Price Simulation']

# %% [markdown]
# We can visualize this by adding the **Scenario** level of the **Source Simulation** hierarchy to a pivot table as shown below.
#
# ![image.png](attachment:1e376fd7-8383-481f-aa10-9106db401683.png)

# %%
session.visualize("Basic Scenario Comparison")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# Currently all the measure values between our scenarios are the same because they are based on the same underlying data.
#
# Now that we have created a scenario we can modify it's data. First let's prepare some modified data where the SellingPricePerUnit of products from each shippers has been scaled...

# %%
scale_factor = {
    "Federal Shipping": 1.05,
    "Speedy Express": 2.0,
    "United Package": 0.5,
    "Rapid Post": 0.8,
    "Freight United": 1.25,
    "The Transporter": 1.1,
}

# %%
orders_df = pd.read_csv(
    "data/Orders.csv", parse_dates=["OrderDate"], infer_datetime_format=True
)

# %%
for shipper, factor in scale_factor.items():
    orders_df.loc[orders_df["ShipperName"] == shipper, "SellingPricePerUnit"] *= factor

# %% [markdown]
# This new dataframe has applied the scaling factor to all the orders based on the particular shipper.

# %%
orders_df.head()
# Out:
#    OrderId  OrderDate  QuantitySold  SellingPricePerUnit     ShipperName  \
# 0        1 2019-02-18           650               28.025  Freight United
# 1        2 2019-02-18           200                4.888      Rapid Post
# 2        3 2019-02-18           830               13.525  United Package
# 3        4 2019-02-18            14               56.020  Speedy Express
# 4        5 2019-02-18           856                6.760      Rapid Post
#
#    ProductId  EmployeeId CustomerId
# 0        994       18336      c4411
# 1       1488       63528      c4299
# 2       1137       18594      c4747
# 3        994       63528      c2171
# 4       1449       18508      c4691

# %% [markdown]
# We can then load our modified data into our new scenario or branch.

# %%
orders.scenarios["Price Simulation"].load_pandas(orders_df)

# %% [markdown]
# Visualizing this, we can add the **Source Simulation** what-if hierarchy to a pivot table in order to see the effect on the SellingPricePerUnit measure between the two branches (or scenarios).
#
# ![image.png](attachment:b59e3912-7dd9-44ed-bb85-fa3b9ce53c9d.png)

# %%
session.visualize("Shippers Scenario Comparison")
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# ## Querying the Cube

# %% [markdown]
# See [Cube operations](https://docs.atoti.io/latest/lib/atoti/atoti.cube.html) for more details.
#
# We can also query the cube without having to use any of the UI widgets.
#
# The results will be returned as a [Pandas data frame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
#
# As a simple example, let's say we wish to run a query returning two measures with two hierarchies on our pivot table, filtering on a specific Shipper...

# %%
queryResults = cube.query(
    measures["QuantitySold.SUM"],
    measures["Sales"],
    levels=[levels["ProductName"], levels["CompanyName"]],
    filter=levels["ShipperName"] == "Speedy Express",
    mode="raw",
)

# %% [markdown]
# The "raw" mode just returns the data in its raw state.
# To prettify it, you can use the "pretty" mode.

# %%
queryResults
# Out:
#    ProductCategory                     ProductName             CompanyName  \
# 0        Beverages                   Côte de Blaye         Du monde entier
# 1        Beverages            Rhönbräu Klosterbier             Wilman Kala
# 2   Grains/Cereals              Gustafs Knäckebröd         Königlich Essen
# 3       Condiments                   Sirop dérable  Océano Atlántico Ltda.
# 4          Produce                   Longlife Tofu      Richter Supermarkt
# ..             ...                             ...                     ...
# 63         Seafood  Jacks New England Clam Chowder     Lehmanns Marktstand
# 64  Dairy Products          Mozzarella di Giovanni        Suprêmes délices
# 65  Dairy Products                Gudbrandsdalsost           Simons bistro
# 66     Confections              Schoggi Schokolade  Princesa Isabel Vinhos
# 67         Seafood                           Ikura           Santé Gourmet
#
#     QuantitySold.SUM     Sales
# 0                120  34081.20
# 1                714   5869.08
# 2                111   2853.81
# 3                154   3814.58
# 4                712   6778.24
# ..               ...       ...
# 63               837   7457.67
# 64               355  10039.40
# 65               172   4661.20
# 66               637  24390.73
# 67               659  19447.09
#
# [68 rows x 5 columns]

# %% [markdown]
# ## Creating Dashboards

# %% [markdown]
# We've already seen the Jupyter notebook embedded **atoti** UI widgets in the previous sections.
#
# We can also launch a separate ActiveUI session which gives us a feature-rich BI (Business Intelligence) user experience...

# %%
session.link()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to see this link.

# %% [markdown]
# # Closing the session
#
# We can stop the cube server session at any time by issuing the following command.
# We would then have to restart a session to continue.

# %%
# session.close()

# %% [markdown]
# # Further Reading

# %% [markdown]
# ## File-watching and Realtime

# %% [markdown]
# **atoti** is able to process incremental data loading into a running cube.
#
# With realtime queries registered in ActiveUI, users will be able to instantly see the effect of these data changes/loads in pivot tables and charts.
#
# See [File Watching](https://docs.atoti.io/latest/how_tos/watch/watch_local_files.html) for more details.

# %% [markdown]
# ## User Security access

# %% [markdown]
# **atoti** can be further customized to provide a security layer for user authentication and authorization.
#
# With **Atoti+**, this can be connected to your organisation's LDAP, ActiveDirectory or SSO setups.
#
# See [security](https://docs.atoti.io/latest/how_tos/security/secure_a_session.html) for more details.

# %% [markdown]
# ## Loading data from different data sources

# %% [markdown]
# Data doesn't have to come from CSV files.
#
# **atoti** supports a variety of plugins and packages to load from:
#
# * [SQL](https://docs.atoti.io/latest/lib/atoti/atoti.table.html#atoti.Table.load_sql) (relational databases)
# * [Parquet](https://docs.atoti.io/latest/lib/atoti/atoti.table.html#atoti.Table.load_parquet)
# * [Spark](https://docs.atoti.io/latest/lib/atoti/atoti.table.html#atoti.Table.load_spark)
# * [Kafka](https://docs.atoti.io/latest/lib/atoti/atoti.table.html#atoti.Table.load_kafka)
# * [AWS](https://docs.atoti.io/latest/lib/atoti-aws/atoti_aws.html#module-atoti_aws) (Amazon Web Services)
# * [Azure](https://docs.atoti.io/latest/lib/atoti-azure/atoti_azure.html)
# * [Pandas data frames](https://docs.atoti.io/latest/lib/atoti/atoti.session.html#atoti.Session.read_pandas)
#
# and with the **atoti+** plugin, [Direct Query](https://docs.atoti.io/latest/how_tos/directquery/use_directquery.html#Use-DirectQuery) can be used to load from:
#
# * [Google Big Query](https://docs.atoti.io/latest/lib/atoti-directquery-bigquery/atoti_directquery_bigquery.html#module-atoti_directquery_bigquery)
# * [Clickhouse](https://docs.atoti.io/latest/lib/atoti-directquery-clickhouse/atoti_directquery_clickhouse.html#module-atoti_directquery_clickhouse)
# * [Snowflake](https://docs.atoti.io/latest/lib/atoti-directquery-snowflake/atoti_directquery_snowflake.html#module-atoti_directquery_snowflake)
# * [Azure Synapse Analytics](https://docs.atoti.io/latest/lib/atoti-directquery-synapse/atoti_directquery_synapse.html#module-atoti_directquery_synapse)

# %% [markdown]
# ## Simulations / what-ifs

# %% [markdown]
# Simulations (or what-ifs) are a way of modifying data to see what the outcome would be when such changes have been applied.
#
# The changes can be seen side-by-side.
#
# Examples may be to change price data, curve data etc to see the effect of such changes.

# %% [markdown]
# See [simulations](https://docs.atoti.io/latest/getting_started/tutorial/tutorial.html#Simulations), [create_parameter_simulation](https://docs.atoti.io/latest/lib/atoti/atoti.cube.html#atoti.Cube.create_parameter_simulation)
# and [Parameter Simulations](https://docs.atoti.io/latest/getting_started/tutorial/tutorial.html#Parameter-simulations)  for more details.
#
# For an example notebook showing simulations in action, see [pnl-explained](https://github.com/atoti/notebooks/tree/main/notebooks/01-use-cases/finance/front-office/pnl-explained)
#
# Simulations or what-ifs utilize branching of datastores allowing alternative branches to compare with the "master" branch.
#
# See [MVCC (Multi-version Concurrency Control)](https://activeviam.com/activepivot/latest/docs/concepts/epoch) for more details.

# %% [markdown]
# ## Math functions

# %% [markdown]
# **atoti** also provides a feature-rech set of mathematical functions in our [math](https://docs.atoti.io/latest/lib/atoti/atoti.math.html) package.

# %% [markdown]
# ## Going Into Production
#
# Commonly, notebooks such as these are made for prototyping and or demonstration purposes. For production-grade applications, additional development is required and different tools are used.
#
# The underlying technology that powers atoti, [ActivePivot](https://activeviam.com/activepivot/latest/), has been used in production systems across many businesses for over a decade.
#
# The atoti team maintains a [project template](https://github.com/atoti/project-template) that provides an example of one way to create a production-ready Python application using atoti or Atoti+.
