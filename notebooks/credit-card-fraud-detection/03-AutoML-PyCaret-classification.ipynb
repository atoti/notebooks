# %%
# ! pip install pycaret

# %% [markdown]
# # Credit Card Fraud Detection with PyCaret
#
# In this notebook, we will test out the autoML [PyCaret](https://pycaret.org/) with reference to its [Binary Classification tutorial](https://github.com/pycaret/pycaret/blob/master/tutorials/Binary%20Classification%20Tutorial%20Level%20Beginner%20-%20%20CLF101.ipynb). Using PyCaret, we will select and train a few models to train the data generated by the [synthetic credit card transactions generator](./01-Synthetic-data-generation.ipynb).
#
# Our ultimate goal is to select a couple of models and use the trained models to perform real-time credit card fraud detection.
# Combined with [atoti](https://atoti.io/), we will compute the impact on key business metrics and also compare the performance of the models.

# %%
import glob
import os
from datetime import date
from zipfile import ZipFile

import numpy as np
import pandas as pd
import wget
from haversine import Unit, haversine
from IPython.display import clear_output, display
from utils import data_prep

# %% [markdown]
# ## 1 Data preparation
#
# ### 1.1 Gather customer and credit card transactions data
#
# You may use the [01-Synthetic-data-generation](./01-Synthetic-data-generation.ipynb) notebook to generate your own data. Alternatively, you can download a saved version of customers and transactions from Jun - Oct 2021.

# %%
data_path = "./output"
profile_path = "./profiles_data"

os.makedirs(data_path, exist_ok=False)

# %% [markdown]
# Skip the below step if data has already been downloaded.

# %%
def bar_custom(current, total, width=80):
    clear_output(wait=True)
    print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))


url = "https://data.atoti.io/notebooks/credit-card-fraud/profiles_data.zip"
filename = wget.download(url, bar=bar_custom)

# unzipping the file
with ZipFile("profiles_data.zip", "r") as zipObj:
    # Extract all the contents of zip file in current directory
    zipObj.extractall()
# Out:
# Downloading: 100% [153865413 / 153865413] bytes

# %% [markdown]
# #### 1.1.1 Process transactions files
#
# We concatenate the transactions for all the profiles into a single DataFrame.

# %%
all_files = glob.glob(profile_path + "/*adults*.csv")

# %%
files = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    files.append(df)

txns_df = pd.concat(files, axis=0, ignore_index=True)
print(
    "Total number of transactions: ",
    len(txns_df),
    " - number of columns: ",
    len(txns_df.columns),
)

txns_df.head()
# Out:
# Total number of transactions:  1276543  - number of columns:  14
#            ssn            cc_num     acct_num                        profile  \
# 0  028-33-9309  4391470058239421  76479233103  adults_2550_female_rural.json
# 1  028-33-9309  4391470058239421  76479233103  adults_2550_female_rural.json
# 2  028-33-9309  4391470058239421  76479233103  adults_2550_female_rural.json
# 3  028-33-9309  4391470058239421  76479233103  adults_2550_female_rural.json
# 4  028-33-9309  4391470058239421  76479233103  adults_2550_female_rural.json
#
#                           trans_num  trans_date trans_time   unix_time  \
# 0  a32d15100140b93f67430a0d51f7f470  2021-08-24   03:09:54  1629774594
# 1  4302c8e427aebde7200b8cb312b092e6  2021-08-23   02:35:13  1629686113
# 2  3e2edc0fa18cb831ab946b3636b2beb4  2021-08-24   23:16:43  1629847003
# 3  a33a6497109e098aa322c904f105d81b  2021-08-24   22:30:43  1629844243
# 4  c902dfaa64a6756f7d0f6e5fbea02284  2021-08-23   01:03:58  1629680638
#
#         category      amt  is_fraud                          merchant  \
# 0  gas_transport     8.78         1             fraud_Prohaska-Murray
# 1    grocery_pos   368.16         1           fraud_Cartwright-Harris
# 2           home   276.14         1              fraud_Beier and Sons
# 3    food_dining   106.20         1  fraud_Kutch, Steuber and Gerhold
# 4   shopping_net  1094.50         1                    fraud_Jast Ltd
#
#    merch_lat  merch_long
# 0  43.469516  -85.860994
# 1  44.040299  -84.026526
# 2  43.735269  -85.122360
# 3  43.432890  -85.804933
# 4  43.245551  -85.220724

# %% [markdown]
# #### 1.1.2 Reducing number of merchants
#
# In the synthetic data generator, merchants' location are computed based on distance from customer. Hence, there may be many merchants of the same name close by. We are going to clean up by combining the same merchants that are close by.

# %%
txns_df = data_prep.merchant_cleanup(txns_df)

# %%
txns_df.sort_values(by=["trans_date", "trans_time"], inplace=True)
txns_df.head()
# Out:
#                  ssn               cc_num      acct_num  \
# 350538   651-85-6277     6011254895433784  650277300926
# 156578   829-65-8471     3561104445052090  359048776675
# 1030583  765-51-3253       30177657960332  457496356031
# 473195   843-90-9424  4893518176925451756  261496133542
# 337806   201-15-2262     3510018921883087  840477491610
#
#                                profile                         trans_num  \
# 350538     adults_2550_male_rural.json  78a301f6c1d629851f2134f3d428bd64
# 156578   adults_2550_female_urban.json  b1f41c9941a8fef0c58b7da9c53b87d1
# 1030583    adults_50up_male_urban.json  4c277b5b47525ffd52919af6c80f292a
# 473195     adults_2550_male_urban.json  a24a9cfd2eb04f1e477c8b2b28f57bd7
# 337806     adults_2550_male_rural.json  2ecedf1776c3de3f8e87cd4842f855f4
#
#          trans_date trans_time   unix_time     category    amt  is_fraud  \
# 350538   2021-06-01   00:03:16  1622505796  grocery_pos  94.07         0
# 156578   2021-06-01   00:05:54  1622505954     misc_net   2.52         0
# 1030583  2021-06-01   00:06:50  1622506010  food_dining  40.44         0
# 473195   2021-06-01   00:09:07  1622506147  grocery_pos  82.00         0
# 337806   2021-06-01   00:10:19  1622506219  grocery_pos  82.95         0
#
#                      merchant  merchant_id  merch_long  merch_lat
# 350538       fraud_Barton Inc       191095  -80.583026  34.505328
# 156578    fraud_Ruecker Group       156108  -74.303208  40.728483
# 1030583     fraud_Haag-Blanda       289878  -87.214427  42.418391
# 473195     fraud_Bauch-Raynor       418020  -97.492732  36.430343
# 337806   fraud_Kiehn-Emmerich       337806  -76.540490  43.925550

# %%
txns_df.shape
# Out:
# (1276543, 15)

# %%
print(
    f"Non-fraudulent: {len(txns_df[txns_df['is_fraud']==0])}, Fraudulent: {len(txns_df[txns_df['is_fraud']==1])}"
)
# Out:
# Non-fraudulent: 1185276, Fraudulent: 91267

# %% [markdown]
# #### 1.1.3 Load customer file

# %%
cust_df = pd.read_csv(f"{profile_path}/customers_list.csv")
cust_df.head()
# Out:
#            ssn            cc_num     first        last gender  \
# 0  535-89-6775   346545733014127     Carla    Sheppard      F
# 1  354-81-2556  3518152160915706     Jaime       Boyle      F
# 2  422-27-9393  5429874770003176      Seth    Mitchell      M
# 3  028-33-9309  4391470058239421  Danielle   Rodriguez      F
# 4  246-23-6185  5395351866032237    Nicole  Villarreal      F
#
#                             street        city state    zip      lat  \
# 0  013 Daniel Trafficway Suite 429  Pittsburgh    PA  15213  40.4440
# 1    88361 Schaefer Cove Suite 452      Lester    AL  35647  34.9596
# 2                 79740 Maria View      Santee    CA  92071  32.8486
# 3     8929 Kenneth Courts Apt. 591        Muir    MI  48860  43.0439
# 4             2655 Rebecca Parkway     Welches    OR  97067  45.3399
#
#        long  city_pop                         job         dob      acct_num  \
# 0  -79.9552    687276  Psychologist, occupational  1938-02-10  438882350784
# 1  -87.1006      1030          Theme park manager  1944-10-08  347776380945
# 2 -116.9862     53422      Engineer, agricultural  1966-07-13   97717754818
# 3  -84.9391      1334   Publishing rights manager  1992-04-12   76479233103
# 4 -121.9598      2138   Education officer, museum  1999-08-22  389654813660
#
#                           profile
# 0   adults_50up_female_urban.json
# 1   adults_50up_female_rural.json
# 2     adults_50up_male_urban.json
# 3   adults_2550_female_rural.json
# 4  young_adults_female_rural.json

# %%
len(cust_df)
# Out:
# 9353

# %% [markdown]
# #### 1.1.4 Compute additional features
#
# The `compute_features` function merge the customers and transactions to compute additional features:
# - customer age
# - distance between customer and merchant
# - time of transaction
#     - Weekday or weekend
#     - Day or night
# - cumulative number of transactions for customer in the past 1, 7 and 30 days
# - cumulative average transaction amount for customer in the past 1, 7 and 30 days

# %%
cc_txn_df = data_prep.compute_features(cust_df, txns_df)

# %%
len(cc_txn_df)
# Out:
# 1276543

# %%
cc_txn_df.tail()
# Out:
#                  ssn            cc_num      acct_num  \
# 1276538  402-78-5680    30306133731849  683914675882
# 1276539  590-91-7122  3525276120447046  301548051587
# 1276540  403-93-5583      639082412268  847752784845
# 1276541  329-13-2201    30179130072305  205446777871
# 1276542  790-64-5257  3552783966051994  573043127801
#
#                                profile                         trans_num  \
# 1276538    adults_50up_male_urban.json  e0570d36e082a5913159e90459f95763
# 1276539   young_adults_male_urban.json  5087d30049ca44c3a8b06f5f16d4400a
# 1276540  adults_2550_female_rural.json  a6f360bf3f1eee039d16a3dffc7caab0
# 1276541  adults_50up_female_urban.json  e2597d6acf0b135cd9e261c257051bb1
# 1276542  adults_50up_female_rural.json  91ae1f2cd55e7d21d4059c2d3bc56bd1
#
#         trans_date trans_time   unix_time       category     amt  ...  age  \
# 1276538 2021-10-31   23:58:08  1635724688       misc_net  780.88  ...   74
# 1276539 2021-10-31   23:58:16  1635724696   shopping_net  900.05  ...   25
# 1276540 2021-10-31   23:58:41  1635724721         travel   10.29  ...   45
# 1276541 2021-10-31   23:59:55  1635724795       misc_net  891.91  ...   75
# 1276542 2021-10-31   23:59:58  1635724798  entertainment  610.12  ...   81
#
#         distance_from_cust  txn_during_night  trans_weekend  nb_txns_1_days  \
# 1276538          87.147193                 1              1             7.0
# 1276539          69.105396                 1              1             8.0
# 1276540         126.952035                 1              1             6.0
# 1276541          98.274275                 1              1             7.0
# 1276542         234.908522                 1              1             4.0
#
#         avg_txns_amt_1_days nb_txns_7_days avg_txns_amt_7_days  \
# 1276538          562.718571           12.0          553.205833
# 1276539          466.542500           17.0          546.149412
# 1276540          412.798333           15.0          312.095333
# 1276541          400.428571           12.0          446.110000
# 1276542          510.600000            7.0          297.687143
#
#         nb_txns_30_days avg_txns_amt_30_days
# 1276538            12.0           553.205833
# 1276539            17.0           546.149412
# 1276540            15.0           312.095333
# 1276541            12.0           446.110000
# 1276542             7.0           297.687143
#
# [5 rows x 37 columns]

# %%
cc_txn_df.columns
# Out:
# Index(['ssn', 'cc_num', 'acct_num', 'profile', 'trans_num', 'trans_date',
#        'trans_time', 'unix_time', 'category', 'amt', 'is_fraud', 'merchant',
#        'merchant_id', 'merch_long', 'merch_lat', 'first', 'last', 'gender',
#        'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job',
#        'dob', 'age', 'distance_from_cust', 'txn_during_night', 'trans_weekend',
#        'nb_txns_1_days', 'avg_txns_amt_1_days', 'nb_txns_7_days',
#        'avg_txns_amt_7_days', 'nb_txns_30_days', 'avg_txns_amt_30_days'],
#       dtype='object')

# %% [markdown]
# ### 1.2 Splitting data for atoti and AutoML
#
# Below are the new columns for transactions and customers after computing the new features.
# We will output these features to CSV for data exploration in atoti.

# %%
txn_new_columns = txns_df.columns.to_list() + [
    "distance_from_cust",
    "txn_during_night",
    "trans_weekend",
    "nb_txns_1_days",
    "avg_txns_amt_1_days",
    "nb_txns_7_days",
    "avg_txns_amt_7_days",
    "nb_txns_30_days",
    "avg_txns_amt_30_days",
]

cust_new_columns = cust_df.columns.to_list() + ["age"]

# %% [markdown]
# We will take data from the first 3 months for exploratory data analysis and data from September for real-time simulation on atoti.

# %%
eda_txn_df = cc_txn_df.loc[cc_txn_df["trans_date"] < "2021-09-01"]
realtime_txn_df = cc_txn_df.loc[
    (cc_txn_df["trans_date"] >= "2021-09-01") & (cc_txn_df["trans_date"] < "2021-10-01")
]

# %% [markdown]
# #### 1.2.1 Export the processed data for EDA in atoti.

# %%
cc_txn_df[cust_new_columns].drop_duplicates().to_csv(
    f"{data_path}/post_process_customer_list.csv", index=False
)

# transaction data for ml modeling and to be loaded into atoti for eda
eda_txn_df[txn_new_columns].to_csv(
    f"{data_path}/post_process_transaction_list.csv", index=False
)

# transaction data to be exported for real-time simulation in atoti
realtime_txn_df[txn_new_columns].to_csv(f"{data_path}/realtime_txn.csv", index=False)

# %% [markdown]
# #### 1.2.2 Split data for machine learning and actual test on unseen data
#
# In the example from [PyCaret tutorial](https://github.com/pycaret/pycaret/blob/master/tutorials/Binary%20Classification%20Tutorial%20Level%20Beginner%20-%20%20CLF101.ipynb), the data set is split into _data_ and _data_unseen_.
#
# In our case, we will use the June data for AutoML, which means that it will be further split into training and testing datasets.
# July data will be used to test the accuracy of the final model.

# %%
june_data = cc_txn_df.loc[cc_txn_df["trans_date"] < "2021-07-01"]
july_aug_data = cc_txn_df.loc[
    (cc_txn_df["trans_date"] >= "2021-07-01") & (cc_txn_df["trans_date"] < "2021-09-01")
]

print(f"June: {len(june_data)} - July & August: {len(july_aug_data)}")
# Out:
# June: 55648 - July & August: 328520

# %%
july_aug_data.tail()
# Out:
#                 ssn            cc_num      acct_num  \
# 384163  717-56-3781   343089588484922  382840886816
# 384164  282-33-3795  4486993221031082  988409340048
# 384165  282-33-3795  4486993221031082  988409340048
# 384166  890-25-8008   341511357666803  156690221471
# 384167  488-44-6293   372091910730620  202299763857
#
#                                profile                         trans_num  \
# 384163     adults_50up_male_rural.json  726c8636d9639403c9e343b35214dc7d
# 384164   adults_2550_female_urban.json  ffaee26ba5112a5b022ee5551d47063f
# 384165   adults_2550_female_urban.json  b23ed48bdbf12f4556c6b76a1e00937e
# 384166  young_adults_female_urban.json  1adeceacd294b7c75a33e5ba925711e6
# 384167     adults_50up_male_rural.json  7c2f6c73a993dcab9d6230a8bc66c972
#
#        trans_date trans_time   unix_time       category     amt  ...  age  \
# 384163 2021-08-31   23:59:12  1630454352           home   28.55  ...   63
# 384164 2021-08-31   23:59:13  1630454353  entertainment  152.87  ...   28
# 384165 2021-08-31   23:59:28  1630454368  personal_care   13.05  ...   28
# 384166 2021-08-31   23:59:35  1630454375  personal_care    3.59  ...   22
# 384167 2021-08-31   23:59:42  1630454382           home   13.50  ...   61
#
#        distance_from_cust  txn_during_night  trans_weekend  nb_txns_1_days  \
# 384163          46.216270                 1              0             3.0
# 384164          90.797907                 1              0             8.0
# 384165          93.939469                 1              0             9.0
# 384166          78.924718                 1              0             4.0
# 384167         116.688540                 1              0             3.0
#
#        avg_txns_amt_1_days nb_txns_7_days avg_txns_amt_7_days nb_txns_30_days  \
# 384163           32.563333           31.0           57.515161           134.0
# 384164           64.378750           32.0           75.802188            32.0
# 384165           58.675556           33.0           73.900606            33.0
# 384166           19.997500           24.0           57.830417            96.0
# 384167          212.280000           19.0           82.588947            56.0
#
#        avg_txns_amt_30_days
# 384163            61.500299
# 384164            75.802188
# 384165            73.900606
# 384166            46.293750
# 384167            61.998750
#
# [5 rows x 37 columns]

# %%
len(july_aug_data)
# Out:
# 328520

# %% [markdown]
# #### 1.2.3 Select features for machine learning
#
# We could have used the [`ignore_features`](https://pycaret.org/classification1/) from PyCaret to ignore some data columns. However, to make it easier to see what are the features that were finally used, we perform filtered selection instead.

# %%
features_list = [
    "category",
    "amt",
    "is_fraud",
    "merchant_id",
    "gender",
    "street",
    "city",
    "state",
    "zip",
    "city_pop",
    "job",
    "age",
    "distance_from_cust",
    "txn_during_night",
    "trans_weekend",
    "nb_txns_1_days",
    "avg_txns_amt_1_days",
    "nb_txns_7_days",
    "avg_txns_amt_7_days",
    "nb_txns_30_days",
    "avg_txns_amt_30_days",
]

# %%
data = june_data[features_list]
data_unseen = july_aug_data[features_list]

# %%
print(f"data: {len(data)} - data_unseen: {len(data_unseen)}")
# Out:
# data: 55648 - data_unseen: 328520

# %% [markdown]
# Reset index for the data in preparation for machine learning.

# %%
data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 2 Testing autoML with PyCaret
#
# ### 2.1 Setting up environment in PyCaret
#
# PyCaret automatically infers the data type. We can [override the inferred data type](https://pycaret.org/data-types/) adding the column names under `numeric_features` or `categorical_features`.
#
# Despite a smaller dataset, we still encountered memory issue. As a workaround, we add the features of high cardinality to the parameter `high_cardinality_features`.
# Note: Uncomment the `ignore_features` below if you would like to exclude the cumulative features from the machine learning model.

# %%
from pycaret.classification import *

clf1 = setup(
    data=data,
    target="is_fraud",
    numeric_features=["txn_during_night", "trans_weekend"],
    categorical_features=["zip", "merchant_id"],
    high_cardinality_features=["street", "city", "state", "zip", "merchant_id"],
    # ignore_features=[
    #     "nb_txns_1_days",
    #     "avg_txns_amt_1_days",
    #     "nb_txns_7_days",
    #     "avg_txns_amt_7_days",
    #     "nb_txns_30_days",
    #     "avg_txns_amt_30_days",
    # ],
)
# Out:
# <style type="text/css">
# #T_b711e_row9_col1, #T_b711e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b711e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b711e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b711e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b711e_row0_col1" class="data row0 col1" >7679</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b711e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b711e_row1_col1" class="data row1 col1" >is_fraud</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b711e_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_b711e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b711e_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_b711e_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b711e_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_b711e_row4_col1" class="data row4 col1" >(55648, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b711e_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_b711e_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b711e_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_b711e_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b711e_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_b711e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b711e_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_b711e_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b711e_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_b711e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b711e_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_b711e_row10_col1" class="data row10 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b711e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_b711e_row11_col1" class="data row11 col1" >(38953, 491)</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b711e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_b711e_row12_col1" class="data row12 col1" >(16695, 491)</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b711e_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_b711e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b711e_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_b711e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b711e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b711e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b711e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b711e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b711e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b711e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b711e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b711e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b711e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b711e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b711e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b711e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b711e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b711e_row21_col1" class="data row21 col1" >f432</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b711e_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_b711e_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b711e_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b711e_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b711e_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_b711e_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b711e_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b711e_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b711e_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_b711e_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b711e_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b711e_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b711e_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b711e_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b711e_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_b711e_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b711e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b711e_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_b711e_row30_col1" class="data row30 col1"

# %% [markdown]
# From the table, we can see that the number of features increased from 21 to 491 due to categorical encoding:
# - The Original Data	(55648, 21)
# - Transformed Train Set	(38953, 491)
# - Transformed Test Set	(16695, 491)

# %% [markdown]
# ### 2.2 Comparing all models
#
# The goal is to be able to detect potential fraud and enable the bank to investigate or alert the consumer of suspicious transactions. Therefore, we will choose a few models with the highest F1 score, AUC and Recall for further comparison.

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_34eac_ th {
#   text-align: left;
# }
# #T_34eac_row0_col0, #T_34eac_row0_col4, #T_34eac_row1_col0, #T_34eac_row1_col1, #T_34eac_row1_col2, #T_34eac_row1_col3, #T_34eac_row1_col4, #T_34eac_row1_col5, #T_34eac_row1_col6, #T_34eac_row1_col7, #T_34eac_row2_col0, #T_34eac_row2_col1, #T_34eac_row2_col2, #T_34eac_row2_col3, #T_34eac_row2_col4, #T_34eac_row2_col5, #T_34eac_row2_col6, #T_34eac_row2_col7, #T_34eac_row3_col0, #T_34eac_row3_col1, #T_34eac_row3_col2, #T_34eac_row3_col3, #T_34eac_row3_col4, #T_34eac_row3_col5, #T_34eac_row3_col6, #T_34eac_row3_col7, #T_34eac_row4_col0, #T_34eac_row4_col1, #T_34eac_row4_col2, #T_34eac_row4_col3, #T_34eac_row4_col5, #T_34eac_row4_col6, #T_34eac_row4_col7, #T_34eac_row5_col0, #T_34eac_row5_col1, #T_34eac_row5_col2, #T_34eac_row5_col3, #T_34eac_row5_col4, #T_34eac_row5_col5, #T_34eac_row5_col6, #T_34eac_row5_col7, #T_34eac_row6_col0, #T_34eac_row6_col1, #T_34eac_row6_col2, #T_34eac_row6_col3, #T_34eac_row6_col4, #T_34eac_row6_col5, #T_34eac_row6_col6, #T_34eac_row6_col7, #T_34eac_row7_col0, #T_34eac_row7_col1, #T_34eac_row7_col2, #T_34eac_row7_col3, #T_34eac_row7_col4, #T_34eac_row7_col5, #T_34eac_row7_col6, #T_34eac_row7_col7, #T_34eac_row8_col0, #T_34eac_row8_col1, #T_34eac_row8_col2, #T_34eac_row8_col3, #T_34eac_row8_col4, #T_34eac_row8_col5, #T_34eac_row8_col6, #T_34eac_row8_col7, #T_34eac_row9_col0, #T_34eac_row9_col1, #T_34eac_row9_col2, #T_34eac_row9_col3, #T_34eac_row9_col4, #T_34eac_row9_col5, #T_34eac_row9_col6, #T_34eac_row9_col7, #T_34eac_row10_col0, #T_34eac_row10_col1, #T_34eac_row10_col2, #T_34eac_row10_col3, #T_34eac_row10_col4, #T_34eac_row10_col5, #T_34eac_row10_col6, #T_34eac_row10_col7, #T_34eac_row11_col0, #T_34eac_row11_col1, #T_34eac_row11_col2, #T_34eac_row11_col3, #T_34eac_row11_col4, #T_34eac_row11_col5, #T_34eac_row11_col6, #T_34eac_row11_col7, #T_34eac_row12_col0, #T_34eac_row12_col1, #T_34eac_row12_col2, #T_34eac_row12_col3, #T_34eac_row12_col4, #T_34eac_row12_col5, #T_34eac_row12_col6, #T_34eac_row12_col7 {
#   text-align: left;
# }
# #T_34eac_row0_col1, #T_34eac_row0_col2, #T_34eac_row0_col3, #T_34eac_row0_col5, #T_34eac_row0_col6, #T_34eac_row0_col7, #T_34eac_row4_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_34eac_row0_col8, #T_34eac_row1_col8, #T_34eac_row2_col8, #T_34eac_row3_col8, #T_34eac_row4_col8, #T_34eac_row5_col8, #T_34eac_row6_col8, #T_34eac_row7_col8, #T_34eac_row8_col8, #T_34eac_row9_col8, #T_34eac_row10_col8, #T_34eac_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_34eac_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_34eac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34eac_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_34eac_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_34eac_row0_col1" class="data row0 col1" >0.9969</td>
#       <td id="T_34eac_row0_col2" class="data row0 col2" >0.9976</td>
#       <td id="T_34eac_row0_col3" class="data row0 col3" >0.8880</td>
#       <td id="T_34eac_row0_col4" class="data row0 col4" >0.9605</td>
#       <td id="T_34eac_row0_col5" class="data row0 col5" >0.9223</td>
#       <td id="T_34eac_row0_col6" class="data row0 col6" >0.9207</td>
#       <td id="T_34eac_row0_col7" class="data row0 col7" >0.9217</td>
#       <td id="T_34eac_row0_col8" class="data row0 col8" >0.3680</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_34eac_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_34eac_row1_col1" class="data row1 col1" >0.9947</td>
#       <td id="T_34eac_row1_col2" class="data row1 col2" >0.9921</td>
#       <td id="T_34eac_row1_col3" class="data row1 col3" >0.8210</td>
#       <td id="T_34eac_row1_col4" class="data row1 col4" >0.9145</td>
#       <td id="T_34eac_row1_col5" class="data row1 col5" >0.8649</td>
#       <td id="T_34eac_row1_col6" class="data row1 col6" >0.8622</td>
#       <td id="T_34eac_row1_col7" class="data row1 col7" >0.8637</td>
#       <td id="T_34eac_row1_col8" class="data row1 col8" >7.2990</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_34eac_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_34eac_row2_col1" class="data row2 col1" >0.9938</td>
#       <td id="T_34eac_row2_col2" class="data row2 col2" >0.9961</td>
#       <td id="T_34eac_row2_col3" class="data row2 col3" >0.7138</td>
#       <td id="T_34eac_row2_col4" class="data row2 col4" >0.9798</td>
#       <td id="T_34eac_row2_col5" class="data row2 col5" >0.8254</td>
#       <td id="T_34eac_row2_col6" class="data row2 col6" >0.8223</td>
#       <td id="T_34eac_row2_col7" class="data row2 col7" >0.8333</td>
#       <td id="T_34eac_row2_col8" class="data row2 col8" >2.1810</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_34eac_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_34eac_row3_col1" class="data row3 col1" >0.9934</td>
#       <td id="T_34eac_row3_col2" class="data row3 col2" >0.9193</td>
#       <td id="T_34eac_row3_col3" class="data row3 col3" >0.8421</td>
#       <td id="T_34eac_row3_col4" class="data row3 col4" >0.8421</td>
#       <td id="T_34eac_row3_col5" class="data row3 col5" >0.8410</td>
#       <td id="T_34eac_row3_col6" class="data row3 col6" >0.8377</td>
#       <td id="T_34eac_row3_col7" class="data row3 col7" >0.8382</td>
#       <td id="T_34eac_row3_col8" class="data row3 col8" >0.5180</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_34eac_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_34eac_row4_col1" class="data row4 col1" >0.9931</td>
#       <td id="T_34eac_row4_col2" class="data row4 col2" >0.9941</td>
#       <td id="T_34eac_row4_col3" class="data row4 col3" >0.6778</td>
#       <td id="T_34eac_row4_col4" class="data row4 col4" >0.9857</td>
#       <td id="T_34eac_row4_col5" class="data row4 col5" >0.8020</td>
#       <td id="T_34eac_row4_col6" class="data row4 col6" >0.7987</td>
#       <td id="T_34eac_row4_col7" class="data row4 col7" >0.8138</td>
#       <td id="T_34eac_row4_col8" class="data row4 col8" >4.4100</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_34eac_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_34eac_row5_col1" class="data row5 col1" >0.9926</td>
#       <td id="T_34eac_row5_col2" class="data row5 col2" >0.9909</td>
#       <td id="T_34eac_row5_col3" class="data row5 col3" >0.7712</td>
#       <td id="T_34eac_row5_col4" class="data row5 col4" >0.8550</td>
#       <td id="T_34eac_row5_col5" class="data row5 col5" >0.8103</td>
#       <td id="T_34eac_row5_col6" class="data row5 col6" >0.8065</td>
#       <td id="T_34eac_row5_col7" class="data row5 col7" >0.8080</td>
#       <td id="T_34eac_row5_col8" class="data row5 col8" >1.9040</td>
#     </tr>
#     <tr>
#       <th id="T_34eac_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_34eac_row6_col0" class="data row6 col0" >K Neighbors Classifier</td>
#       <td id="T_34eac_row6_col1" class="data row6 col1" >0.9882</td>
#       <td id="T_34eac_row6_col2" class="data row6 col2" >0.9252</td>
#       <td id="T_34eac_row

# %%
best_model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=7679, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# ### 2.3 Creating models
#
# Let's create the model for a few of those with highest F1 score and AUC. In fraud detection, we aim to raise alert to the credit cardholder of suspicious transactions. Hence, we will take the model that scored well for both AUC and recall.
#
# #### 2.3.1 Decision Tree Classifier

# %%
dt = create_model("dt")
# Out:
# <style type="text/css">
# #T_47fbf_row10_col0, #T_47fbf_row10_col1, #T_47fbf_row10_col2, #T_47fbf_row10_col3, #T_47fbf_row10_col4, #T_47fbf_row10_col5, #T_47fbf_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_47fbf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47fbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47fbf_row0_col0" class="data row0 col0" >0.9931</td>
#       <td id="T_47fbf_row0_col1" class="data row0 col1" >0.9421</td>
#       <td id="T_47fbf_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_47fbf_row0_col3" class="data row0 col3" >0.8000</td>
#       <td id="T_47fbf_row0_col4" class="data row0 col4" >0.8421</td>
#       <td id="T_47fbf_row0_col5" class="data row0 col5" >0.8386</td>
#       <td id="T_47fbf_row0_col6" class="data row0 col6" >0.8398</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47fbf_row1_col0" class="data row1 col0" >0.9938</td>
#       <td id="T_47fbf_row1_col1" class="data row1 col1" >0.9244</td>
#       <td id="T_47fbf_row1_col2" class="data row1 col2" >0.8519</td>
#       <td id="T_47fbf_row1_col3" class="data row1 col3" >0.8519</td>
#       <td id="T_47fbf_row1_col4" class="data row1 col4" >0.8519</td>
#       <td id="T_47fbf_row1_col5" class="data row1 col5" >0.8487</td>
#       <td id="T_47fbf_row1_col6" class="data row1 col6" >0.8487</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47fbf_row2_col0" class="data row2 col0" >0.9931</td>
#       <td id="T_47fbf_row2_col1" class="data row2 col1" >0.8817</td>
#       <td id="T_47fbf_row2_col2" class="data row2 col2" >0.7654</td>
#       <td id="T_47fbf_row2_col3" class="data row2 col3" >0.8857</td>
#       <td id="T_47fbf_row2_col4" class="data row2 col4" >0.8212</td>
#       <td id="T_47fbf_row2_col5" class="data row2 col5" >0.8177</td>
#       <td id="T_47fbf_row2_col6" class="data row2 col6" >0.8199</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47fbf_row3_col0" class="data row3 col0" >0.9936</td>
#       <td id="T_47fbf_row3_col1" class="data row3 col1" >0.9478</td>
#       <td id="T_47fbf_row3_col2" class="data row3 col2" >0.9000</td>
#       <td id="T_47fbf_row3_col3" class="data row3 col3" >0.8090</td>
#       <td id="T_47fbf_row3_col4" class="data row3 col4" >0.8521</td>
#       <td id="T_47fbf_row3_col5" class="data row3 col5" >0.8488</td>
#       <td id="T_47fbf_row3_col6" class="data row3 col6" >0.8501</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47fbf_row4_col0" class="data row4 col0" >0.9926</td>
#       <td id="T_47fbf_row4_col1" class="data row4 col1" >0.9044</td>
#       <td id="T_47fbf_row4_col2" class="data row4 col2" >0.8125</td>
#       <td id="T_47fbf_row4_col3" class="data row4 col3" >0.8228</td>
#       <td id="T_47fbf_row4_col4" class="data row4 col4" >0.8176</td>
#       <td id="T_47fbf_row4_col5" class="data row4 col5" >0.8138</td>
#       <td id="T_47fbf_row4_col6" class="data row4 col6" >0.8138</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47fbf_row5_col0" class="data row5 col0" >0.9944</td>
#       <td id="T_47fbf_row5_col1" class="data row5 col1" >0.9237</td>
#       <td id="T_47fbf_row5_col2" class="data row5 col2" >0.8500</td>
#       <td id="T_47fbf_row5_col3" class="data row5 col3" >0.8718</td>
#       <td id="T_47fbf_row5_col4" class="data row5 col4" >0.8608</td>
#       <td id="T_47fbf_row5_col5" class="data row5 col5" >0.8579</td>
#       <td id="T_47fbf_row5_col6" class="data row5 col6" >0.8579</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47fbf_row6_col0" class="data row6 col0" >0.9972</td>
#       <td id="T_47fbf_row6_col1" class="data row6 col1" >0.9618</td>
#       <td id="T_47fbf_row6_col2" class="data row6 col2" >0.9250</td>
#       <td id="T_47fbf_row6_col3" class="data row6 col3" >0.9367</td>
#       <td id="T_47fbf_row6_col4" class="data row6 col4" >0.9308</td>
#       <td id="T_47fbf_row6_col5" class="data row6 col5" >0.9294</td>
#       <td id="T_47fbf_row6_col6" class="data row6 col6" >0.9294</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47fbf_row7_col0" class="data row7 col0" >0.9897</td>
#       <td id="T_47fbf_row7_col1" class="data row7 col1" >0.8785</td>
#       <td id="T_47fbf_row7_col2" class="data row7 col2" >0.7625</td>
#       <td id="T_47fbf_row7_col3" class="data row7 col3" >0.7439</td>
#       <td id="T_47fbf_row7_col4" class="data row7 col4" >0.7531</td>
#       <td id="T_47fbf_row7_col5" class="data row7 col5" >0.7478</td>
#       <td id="T_47fbf_row7_col6" class="data row7 col6" >0.7479</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47fbf_row8_col0" class="data row8 col0" >0.9941</td>
#       <td id="T_47fbf_row8_col1" class="data row8 col1" >0.9113</td>
#       <td id="T_47fbf_row8_col2" class="data row8 col2" >0.8250</td>
#       <td id="T_47fbf_row8_col3" class="data row8 col3" >0.8800</td>
#       <td id="T_47fbf_row8_col4" class="data row8 col4" >0.8516</td>
#       <td id="T_47fbf_row8_col5" class="data row8 col5" >0.8486</td>
#       <td id="T_47fbf_row8_col6" class="data row8 col6" >0.8491</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47fbf_row9_col0" class="data row9 col0" >0.9928</td>
#       <td id="T_47fbf_row9_col1" class="data row9 col1" >0.9178</td>
#       <td id="T_47fbf_row9_col2" class="data row9 col2" >0.8395</td>
#       <td id="T_47fbf_row9_col3" class="data row9 col3" >0.8193</td>
#       <td id="T_47fbf_row9_col4" class="data row9 col4" >0.8293</td>
#       <td id="T_47fbf_row9_col5" class="data row9 col5" >0.8256</td>
#       <td id="T_47fbf_row9_col6" class="data row9 col6" >0.8257</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_47fbf_row10_col0" class="data row10 col0" >0.9934</td>
#       <td id="T_47fbf_row10_col1" class="data row10 col1" >0.9193</td>
#       <td id="T_47fbf_row10_col2" class="data row10 col2" >0.8421</td>
#       <td id="T_47fbf_row10_col3" class="data row10 col3" >0.8421</td>
#       <td id="T_47fbf_row10_col4" class="data row10 col4" >0.8410</td>
#       <td id="T_47fbf_row10_col5" class="data row10 col5" >0.8377</td>
#       <td id="T_47fbf_row10_col6" class="data row10 col6" >0.8382</td>
#     </tr>
#     <tr>
#       <th id="T_47fbf_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_47fbf_row11_col0" class="data row11 col0" >0.0017</td>
#       <td id="T_47fbf_row11_col1" class="data row11 col1" >0.0256</td>
#       <td id="T_47fbf_row11_col2" class="data row11 col2" >0.0510</td>
#       <td id="T_47fbf_row11_col3" class="data row11 col3" >0.0516</td>
#       <td id="T_47fbf_row11_col4" class="data row11 col4" >0.0420</td>
#       <td id="T_47fbf_row11_col5" class="data row11 col5" >0.0429</td>
#       <td id="T_47fbf_row11_col6" class="data row11 col6" >0.0428</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 2.3.2 Extra Trees Classifier

# %%
et = create_model("et")
# Out:
# <style type="text/css">
# #T_307a4_row10_col0, #T_307a4_row10_col1, #T_307a4_row10_col2, #T_307a4_row10_col3, #T_307a4_row10_col4, #T_307a4_row10_col5, #T_307a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_307a4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_307a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_307a4_row0_col0" class="data row0 col0" >0.9938</td>
#       <td id="T_307a4_row0_col1" class="data row0 col1" >0.9905</td>
#       <td id="T_307a4_row0_col2" class="data row0 col2" >0.7160</td>
#       <td id="T_307a4_row0_col3" class="data row0 col3" >0.9831</td>
#       <td id="T_307a4_row0_col4" class="data row0 col4" >0.8286</td>
#       <td id="T_307a4_row0_col5" class="data row0 col5" >0.8255</td>
#       <td id="T_307a4_row0_col6" class="data row0 col6" >0.8363</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_307a4_row1_col0" class="data row1 col0" >0.9920</td>
#       <td id="T_307a4_row1_col1" class="data row1 col1" >0.9986</td>
#       <td id="T_307a4_row1_col2" class="data row1 col2" >0.6296</td>
#       <td id="T_307a4_row1_col3" class="data row1 col3" >0.9808</td>
#       <td id="T_307a4_row1_col4" class="data row1 col4" >0.7669</td>
#       <td id="T_307a4_row1_col5" class="data row1 col5" >0.7631</td>
#       <td id="T_307a4_row1_col6" class="data row1 col6" >0.7825</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_307a4_row2_col0" class="data row2 col0" >0.9936</td>
#       <td id="T_307a4_row2_col1" class="data row2 col1" >0.9981</td>
#       <td id="T_307a4_row2_col2" class="data row2 col2" >0.7037</td>
#       <td id="T_307a4_row2_col3" class="data row2 col3" >0.9828</td>
#       <td id="T_307a4_row2_col4" class="data row2 col4" >0.8201</td>
#       <td id="T_307a4_row2_col5" class="data row2 col5" >0.8170</td>
#       <td id="T_307a4_row2_col6" class="data row2 col6" >0.8288</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_307a4_row3_col0" class="data row3 col0" >0.9933</td>
#       <td id="T_307a4_row3_col1" class="data row3 col1" >0.9874</td>
#       <td id="T_307a4_row3_col2" class="data row3 col2" >0.6750</td>
#       <td id="T_307a4_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_307a4_row3_col4" class="data row3 col4" >0.8060</td>
#       <td id="T_307a4_row3_col5" class="data row3 col5" >0.8027</td>
#       <td id="T_307a4_row3_col6" class="data row3 col6" >0.8188</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_307a4_row4_col0" class="data row4 col0" >0.9944</td>
#       <td id="T_307a4_row4_col1" class="data row4 col1" >0.9972</td>
#       <td id="T_307a4_row4_col2" class="data row4 col2" >0.7250</td>
#       <td id="T_307a4_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_307a4_row4_col4" class="data row4 col4" >0.8406</td>
#       <td id="T_307a4_row4_col5" class="data row4 col5" >0.8378</td>
#       <td id="T_307a4_row4_col6" class="data row4 col6" >0.8490</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_307a4_row5_col0" class="data row5 col0" >0.9938</td>
#       <td id="T_307a4_row5_col1" class="data row5 col1" >0.9914</td>
#       <td id="T_307a4_row5_col2" class="data row5 col2" >0.7125</td>
#       <td id="T_307a4_row5_col3" class="data row5 col3" >0.9828</td>
#       <td id="T_307a4_row5_col4" class="data row5 col4" >0.8261</td>
#       <td id="T_307a4_row5_col5" class="data row5 col5" >0.8230</td>
#       <td id="T_307a4_row5_col6" class="data row5 col6" >0.8341</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_307a4_row6_col0" class="data row6 col0" >0.9944</td>
#       <td id="T_307a4_row6_col1" class="data row6 col1" >0.9991</td>
#       <td id="T_307a4_row6_col2" class="data row6 col2" >0.7250</td>
#       <td id="T_307a4_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_307a4_row6_col4" class="data row6 col4" >0.8406</td>
#       <td id="T_307a4_row6_col5" class="data row6 col5" >0.8378</td>
#       <td id="T_307a4_row6_col6" class="data row6 col6" >0.8490</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_307a4_row7_col0" class="data row7 col0" >0.9915</td>
#       <td id="T_307a4_row7_col1" class="data row7 col1" >0.9897</td>
#       <td id="T_307a4_row7_col2" class="data row7 col2" >0.6375</td>
#       <td id="T_307a4_row7_col3" class="data row7 col3" >0.9273</td>
#       <td id="T_307a4_row7_col4" class="data row7 col4" >0.7556</td>
#       <td id="T_307a4_row7_col5" class="data row7 col5" >0.7514</td>
#       <td id="T_307a4_row7_col6" class="data row7 col6" >0.7651</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_307a4_row8_col0" class="data row8 col0" >0.9908</td>
#       <td id="T_307a4_row8_col1" class="data row8 col1" >0.9904</td>
#       <td id="T_307a4_row8_col2" class="data row8 col2" >0.5500</td>
#       <td id="T_307a4_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_307a4_row8_col4" class="data row8 col4" >0.7097</td>
#       <td id="T_307a4_row8_col5" class="data row8 col5" >0.7054</td>
#       <td id="T_307a4_row8_col6" class="data row8 col6" >0.7381</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_307a4_row9_col0" class="data row9 col0" >0.9938</td>
#       <td id="T_307a4_row9_col1" class="data row9 col1" >0.9986</td>
#       <td id="T_307a4_row9_col2" class="data row9 col2" >0.7037</td>
#       <td id="T_307a4_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_307a4_row9_col4" class="data row9 col4" >0.8261</td>
#       <td id="T_307a4_row9_col5" class="data row9 col5" >0.8230</td>
#       <td id="T_307a4_row9_col6" class="data row9 col6" >0.8362</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_307a4_row10_col0" class="data row10 col0" >0.9931</td>
#       <td id="T_307a4_row10_col1" class="data row10 col1" >0.9941</td>
#       <td id="T_307a4_row10_col2" class="data row10 col2" >0.6778</td>
#       <td id="T_307a4_row10_col3" class="data row10 col3" >0.9857</td>
#       <td id="T_307a4_row10_col4" class="data row10 col4" >0.8020</td>
#       <td id="T_307a4_row10_col5" class="data row10 col5" >0.7987</td>
#       <td id="T_307a4_row10_col6" class="data row10 col6" >0.8138</td>
#     </tr>
#     <tr>
#       <th id="T_307a4_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_307a4_row11_col0" class="data row11 col0" >0.0012</td>
#       <td id="T_307a4_row11_col1" class="data row11 col1" >0.0043</td>
#       <td id="T_307a4_row11_col2" class="data row11 col2" >0.0536</td>
#       <td id="T_307a4_row11_col3" class="data row11 col3" >0.0212</td>
#       <td id="T_307a4_row11_col4" class="data row11 col4" >0.0414</td>
#       <td id="T_307a4_row11_col5" class="data row11 col5" >0.0419</td>
#       <td id="T_307a4_row11_col6" class="data row11 col6" >0.0364</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 2.3.3 Light Gradient Boosting Machine

# %%
lgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_7a25b_row10_col0, #T_7a25b_row10_col1, #T_7a25b_row10_col2, #T_7a25b_row10_col3, #T_7a25b_row10_col4, #T_7a25b_row10_col5, #T_7a25b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7a25b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a25b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a25b_row0_col0" class="data row0 col0" >0.9974</td>
#       <td id="T_7a25b_row0_col1" class="data row0 col1" >0.9986</td>
#       <td id="T_7a25b_row0_col2" class="data row0 col2" >0.9136</td>
#       <td id="T_7a25b_row0_col3" class="data row0 col3" >0.9610</td>
#       <td id="T_7a25b_row0_col4" class="data row0 col4" >0.9367</td>
#       <td id="T_7a25b_row0_col5" class="data row0 col5" >0.9354</td>
#       <td id="T_7a25b_row0_col6" class="data row0 col6" >0.9357</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a25b_row1_col0" class="data row1 col0" >0.9967</td>
#       <td id="T_7a25b_row1_col1" class="data row1 col1" >0.9995</td>
#       <td id="T_7a25b_row1_col2" class="data row1 col2" >0.9012</td>
#       <td id="T_7a25b_row1_col3" class="data row1 col3" >0.9359</td>
#       <td id="T_7a25b_row1_col4" class="data row1 col4" >0.9182</td>
#       <td id="T_7a25b_row1_col5" class="data row1 col5" >0.9165</td>
#       <td id="T_7a25b_row1_col6" class="data row1 col6" >0.9167</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a25b_row2_col0" class="data row2 col0" >0.9967</td>
#       <td id="T_7a25b_row2_col1" class="data row2 col1" >0.9975</td>
#       <td id="T_7a25b_row2_col2" class="data row2 col2" >0.8889</td>
#       <td id="T_7a25b_row2_col3" class="data row2 col3" >0.9474</td>
#       <td id="T_7a25b_row2_col4" class="data row2 col4" >0.9172</td>
#       <td id="T_7a25b_row2_col5" class="data row2 col5" >0.9155</td>
#       <td id="T_7a25b_row2_col6" class="data row2 col6" >0.9160</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a25b_row3_col0" class="data row3 col0" >0.9969</td>
#       <td id="T_7a25b_row3_col1" class="data row3 col1" >0.9987</td>
#       <td id="T_7a25b_row3_col2" class="data row3 col2" >0.8875</td>
#       <td id="T_7a25b_row3_col3" class="data row3 col3" >0.9595</td>
#       <td id="T_7a25b_row3_col4" class="data row3 col4" >0.9221</td>
#       <td id="T_7a25b_row3_col5" class="data row3 col5" >0.9205</td>
#       <td id="T_7a25b_row3_col6" class="data row3 col6" >0.9212</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a25b_row4_col0" class="data row4 col0" >0.9956</td>
#       <td id="T_7a25b_row4_col1" class="data row4 col1" >0.9975</td>
#       <td id="T_7a25b_row4_col2" class="data row4 col2" >0.8000</td>
#       <td id="T_7a25b_row4_col3" class="data row4 col3" >0.9846</td>
#       <td id="T_7a25b_row4_col4" class="data row4 col4" >0.8828</td>
#       <td id="T_7a25b_row4_col5" class="data row4 col5" >0.8806</td>
#       <td id="T_7a25b_row4_col6" class="data row4 col6" >0.8855</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a25b_row5_col0" class="data row5 col0" >0.9959</td>
#       <td id="T_7a25b_row5_col1" class="data row5 col1" >0.9927</td>
#       <td id="T_7a25b_row5_col2" class="data row5 col2" >0.8875</td>
#       <td id="T_7a25b_row5_col3" class="data row5 col3" >0.9103</td>
#       <td id="T_7a25b_row5_col4" class="data row5 col4" >0.8987</td>
#       <td id="T_7a25b_row5_col5" class="data row5 col5" >0.8966</td>
#       <td id="T_7a25b_row5_col6" class="data row5 col6" >0.8967</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a25b_row6_col0" class="data row6 col0" >0.9979</td>
#       <td id="T_7a25b_row6_col1" class="data row6 col1" >0.9997</td>
#       <td id="T_7a25b_row6_col2" class="data row6 col2" >0.9250</td>
#       <td id="T_7a25b_row6_col3" class="data row6 col3" >0.9737</td>
#       <td id="T_7a25b_row6_col4" class="data row6 col4" >0.9487</td>
#       <td id="T_7a25b_row6_col5" class="data row6 col5" >0.9477</td>
#       <td id="T_7a25b_row6_col6" class="data row6 col6" >0.9480</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a25b_row7_col0" class="data row7 col0" >0.9977</td>
#       <td id="T_7a25b_row7_col1" class="data row7 col1" >0.9932</td>
#       <td id="T_7a25b_row7_col2" class="data row7 col2" >0.9125</td>
#       <td id="T_7a25b_row7_col3" class="data row7 col3" >0.9733</td>
#       <td id="T_7a25b_row7_col4" class="data row7 col4" >0.9419</td>
#       <td id="T_7a25b_row7_col5" class="data row7 col5" >0.9408</td>
#       <td id="T_7a25b_row7_col6" class="data row7 col6" >0.9413</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a25b_row8_col0" class="data row8 col0" >0.9979</td>
#       <td id="T_7a25b_row8_col1" class="data row8 col1" >0.9991</td>
#       <td id="T_7a25b_row8_col2" class="data row8 col2" >0.9000</td>
#       <td id="T_7a25b_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_7a25b_row8_col4" class="data row8 col4" >0.9474</td>
#       <td id="T_7a25b_row8_col5" class="data row8 col5" >0.9463</td>
#       <td id="T_7a25b_row8_col6" class="data row8 col6" >0.9477</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a25b_row9_col0" class="data row9 col0" >0.9964</td>
#       <td id="T_7a25b_row9_col1" class="data row9 col1" >0.9994</td>
#       <td id="T_7a25b_row9_col2" class="data row9 col2" >0.8642</td>
#       <td id="T_7a25b_row9_col3" class="data row9 col3" >0.9589</td>
#       <td id="T_7a25b_row9_col4" class="data row9 col4" >0.9091</td>
#       <td id="T_7a25b_row9_col5" class="data row9 col5" >0.9073</td>
#       <td id="T_7a25b_row9_col6" class="data row9 col6" >0.9085</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7a25b_row10_col0" class="data row10 col0" >0.9969</td>
#       <td id="T_7a25b_row10_col1" class="data row10 col1" >0.9976</td>
#       <td id="T_7a25b_row10_col2" class="data row10 col2" >0.8880</td>
#       <td id="T_7a25b_row10_col3" class="data row10 col3" >0.9605</td>
#       <td id="T_7a25b_row10_col4" class="data row10 col4" >0.9223</td>
#       <td id="T_7a25b_row10_col5" class="data row10 col5" >0.9207</td>
#       <td id="T_7a25b_row10_col6" class="data row10 col6" >0.9217</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_7a25b_row11_col0" class="data row11 col0" >0.0008</td>
#       <td id="T_7a25b_row11_col1" class="data row11 col1" >0.0024</td>
#       <td id="T_7a25b_row11_col2" class="data row11 col2" >0.0335</td>
#       <td id="T_7a25b_row11_col3" class="data row11 col3" >0.0241</td>
#       <td id="T_7a25b_row11_col4" class="data row11 col4" >0.0206</td>
#       <td id="T_7a25b_row11_col5" class="data row11 col5" >0.0210</td>
#       <td id="T_7a25b_row11_col6" class="data row11 col6" >0.0203</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.4 Tune models
#
# `create_model()` trains the model using default hyperparameters. We will use `tune_model()` function to tune the hyperparameters.

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_ea75a_row10_col0, #T_ea75a_row10_col1, #T_ea75a_row10_col2, #T_ea75a_row10_col3, #T_ea75a_row10_col4, #T_ea75a_row10_col5, #T_ea75a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ea75a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea75a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea75a_row0_col0" class="data row0 col0" >0.9915</td>
#       <td id="T_ea75a_row0_col1" class="data row0 col1" >0.9488</td>
#       <td id="T_ea75a_row0_col2" class="data row0 col2" >0.7531</td>
#       <td id="T_ea75a_row0_col3" class="data row0 col3" >0.8243</td>
#       <td id="T_ea75a_row0_col4" class="data row0 col4" >0.7871</td>
#       <td id="T_ea75a_row0_col5" class="data row0 col5" >0.7828</td>
#       <td id="T_ea75a_row0_col6" class="data row0 col6" >0.7836</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea75a_row1_col0" class="data row1 col0" >0.9882</td>
#       <td id="T_ea75a_row1_col1" class="data row1 col1" >0.9007</td>
#       <td id="T_ea75a_row1_col2" class="data row1 col2" >0.5556</td>
#       <td id="T_ea75a_row1_col3" class="data row1 col3" >0.8182</td>
#       <td id="T_ea75a_row1_col4" class="data row1 col4" >0.6618</td>
#       <td id="T_ea75a_row1_col5" class="data row1 col5" >0.6560</td>
#       <td id="T_ea75a_row1_col6" class="data row1 col6" >0.6687</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea75a_row2_col0" class="data row2 col0" >0.9884</td>
#       <td id="T_ea75a_row2_col1" class="data row2 col1" >0.9506</td>
#       <td id="T_ea75a_row2_col2" class="data row2 col2" >0.6790</td>
#       <td id="T_ea75a_row2_col3" class="data row2 col3" >0.7432</td>
#       <td id="T_ea75a_row2_col4" class="data row2 col4" >0.7097</td>
#       <td id="T_ea75a_row2_col5" class="data row2 col5" >0.7038</td>
#       <td id="T_ea75a_row2_col6" class="data row2 col6" >0.7045</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea75a_row3_col0" class="data row3 col0" >0.9866</td>
#       <td id="T_ea75a_row3_col1" class="data row3 col1" >0.9124</td>
#       <td id="T_ea75a_row3_col2" class="data row3 col2" >0.6375</td>
#       <td id="T_ea75a_row3_col3" class="data row3 col3" >0.6892</td>
#       <td id="T_ea75a_row3_col4" class="data row3 col4" >0.6623</td>
#       <td id="T_ea75a_row3_col5" class="data row3 col5" >0.6555</td>
#       <td id="T_ea75a_row3_col6" class="data row3 col6" >0.6561</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea75a_row4_col0" class="data row4 col0" >0.9874</td>
#       <td id="T_ea75a_row4_col1" class="data row4 col1" >0.9281</td>
#       <td id="T_ea75a_row4_col2" class="data row4 col2" >0.7000</td>
#       <td id="T_ea75a_row4_col3" class="data row4 col3" >0.6914</td>
#       <td id="T_ea75a_row4_col4" class="data row4 col4" >0.6957</td>
#       <td id="T_ea75a_row4_col5" class="data row4 col5" >0.6892</td>
#       <td id="T_ea75a_row4_col6" class="data row4 col6" >0.6892</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea75a_row5_col0" class="data row5 col0" >0.9892</td>
#       <td id="T_ea75a_row5_col1" class="data row5 col1" >0.9314</td>
#       <td id="T_ea75a_row5_col2" class="data row5 col2" >0.6875</td>
#       <td id="T_ea75a_row5_col3" class="data row5 col3" >0.7639</td>
#       <td id="T_ea75a_row5_col4" class="data row5 col4" >0.7237</td>
#       <td id="T_ea75a_row5_col5" class="data row5 col5" >0.7182</td>
#       <td id="T_ea75a_row5_col6" class="data row5 col6" >0.7192</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea75a_row6_col0" class="data row6 col0" >0.9892</td>
#       <td id="T_ea75a_row6_col1" class="data row6 col1" >0.9219</td>
#       <td id="T_ea75a_row6_col2" class="data row6 col2" >0.6750</td>
#       <td id="T_ea75a_row6_col3" class="data row6 col3" >0.7714</td>
#       <td id="T_ea75a_row6_col4" class="data row6 col4" >0.7200</td>
#       <td id="T_ea75a_row6_col5" class="data row6 col5" >0.7145</td>
#       <td id="T_ea75a_row6_col6" class="data row6 col6" >0.7162</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea75a_row7_col0" class="data row7 col0" >0.9874</td>
#       <td id="T_ea75a_row7_col1" class="data row7 col1" >0.9367</td>
#       <td id="T_ea75a_row7_col2" class="data row7 col2" >0.6625</td>
#       <td id="T_ea75a_row7_col3" class="data row7 col3" >0.7067</td>
#       <td id="T_ea75a_row7_col4" class="data row7 col4" >0.6839</td>
#       <td id="T_ea75a_row7_col5" class="data row7 col5" >0.6775</td>
#       <td id="T_ea75a_row7_col6" class="data row7 col6" >0.6778</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ea75a_row8_col0" class="data row8 col0" >0.9900</td>
#       <td id="T_ea75a_row8_col1" class="data row8 col1" >0.9473</td>
#       <td id="T_ea75a_row8_col2" class="data row8 col2" >0.6375</td>
#       <td id="T_ea75a_row8_col3" class="data row8 col3" >0.8361</td>
#       <td id="T_ea75a_row8_col4" class="data row8 col4" >0.7234</td>
#       <td id="T_ea75a_row8_col5" class="data row8 col5" >0.7184</td>
#       <td id="T_ea75a_row8_col6" class="data row8 col6" >0.7253</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ea75a_row9_col0" class="data row9 col0" >0.9884</td>
#       <td id="T_ea75a_row9_col1" class="data row9 col1" >0.9330</td>
#       <td id="T_ea75a_row9_col2" class="data row9 col2" >0.6296</td>
#       <td id="T_ea75a_row9_col3" class="data row9 col3" >0.7727</td>
#       <td id="T_ea75a_row9_col4" class="data row9 col4" >0.6939</td>
#       <td id="T_ea75a_row9_col5" class="data row9 col5" >0.6881</td>
#       <td id="T_ea75a_row9_col6" class="data row9 col6" >0.6918</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ea75a_row10_col0" class="data row10 col0" >0.9887</td>
#       <td id="T_ea75a_row10_col1" class="data row10 col1" >0.9311</td>
#       <td id="T_ea75a_row10_col2" class="data row10 col2" >0.6617</td>
#       <td id="T_ea75a_row10_col3" class="data row10 col3" >0.7617</td>
#       <td id="T_ea75a_row10_col4" class="data row10 col4" >0.7061</td>
#       <td id="T_ea75a_row10_col5" class="data row10 col5" >0.7004</td>
#       <td id="T_ea75a_row10_col6" class="data row10 col6" >0.7033</td>
#     </tr>
#     <tr>
#       <th id="T_ea75a_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_ea75a_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_ea75a_row11_col1" class="data row11 col1" >0.0154</td>
#       <td id="T_ea75a_row11_col2" class="data row11 col2" >0.0494</td>
#       <td id="T_ea75a_row11_col3" class="data row11 col3" >0.0514</td>
#       <td id="T_ea75a_row11_col4" class="data row11 col4" >0.0347</td>
#       <td id="T_ea75a_row11_col5" class="data row11 col5" >0.0353</td>
#       <td id="T_ea75a_row11_col6" class="data row11 col6" >0.0343</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_et = tune_model(et)
# Out:
# <style type="text/css">
# #T_8da72_row10_col0, #T_8da72_row10_col1, #T_8da72_row10_col2, #T_8da72_row10_col3, #T_8da72_row10_col4, #T_8da72_row10_col5, #T_8da72_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8da72_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8da72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8da72_row0_col0" class="data row0 col0" >0.9792</td>
#       <td id="T_8da72_row0_col1" class="data row0 col1" >0.9479</td>
#       <td id="T_8da72_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_8da72_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_8da72_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_8da72_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_8da72_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8da72_row1_col0" class="data row1 col0" >0.9792</td>
#       <td id="T_8da72_row1_col1" class="data row1 col1" >0.9486</td>
#       <td id="T_8da72_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_8da72_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_8da72_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_8da72_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_8da72_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8da72_row2_col0" class="data row2 col0" >0.9792</td>
#       <td id="T_8da72_row2_col1" class="data row2 col1" >0.9501</td>
#       <td id="T_8da72_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_8da72_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_8da72_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_8da72_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_8da72_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8da72_row3_col0" class="data row3 col0" >0.9795</td>
#       <td id="T_8da72_row3_col1" class="data row3 col1" >0.9227</td>
#       <td id="T_8da72_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_8da72_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_8da72_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_8da72_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_8da72_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8da72_row4_col0" class="data row4 col0" >0.9795</td>
#       <td id="T_8da72_row4_col1" class="data row4 col1" >0.9144</td>
#       <td id="T_8da72_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_8da72_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_8da72_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_8da72_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_8da72_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8da72_row5_col0" class="data row5 col0" >0.9795</td>
#       <td id="T_8da72_row5_col1" class="data row5 col1" >0.9476</td>
#       <td id="T_8da72_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_8da72_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_8da72_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_8da72_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_8da72_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8da72_row6_col0" class="data row6 col0" >0.9795</td>
#       <td id="T_8da72_row6_col1" class="data row6 col1" >0.9530</td>
#       <td id="T_8da72_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_8da72_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_8da72_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_8da72_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_8da72_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8da72_row7_col0" class="data row7 col0" >0.9795</td>
#       <td id="T_8da72_row7_col1" class="data row7 col1" >0.9216</td>
#       <td id="T_8da72_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_8da72_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_8da72_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_8da72_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_8da72_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8da72_row8_col0" class="data row8 col0" >0.9795</td>
#       <td id="T_8da72_row8_col1" class="data row8 col1" >0.8738</td>
#       <td id="T_8da72_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_8da72_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_8da72_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_8da72_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_8da72_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8da72_row9_col0" class="data row9 col0" >0.9792</td>
#       <td id="T_8da72_row9_col1" class="data row9 col1" >0.8866</td>
#       <td id="T_8da72_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_8da72_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_8da72_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_8da72_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_8da72_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8da72_row10_col0" class="data row10 col0" >0.9794</td>
#       <td id="T_8da72_row10_col1" class="data row10 col1" >0.9266</td>
#       <td id="T_8da72_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_8da72_row10_col3" class="data row10 col3" >0.0000</td>
#       <td id="T_8da72_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_8da72_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_8da72_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8da72_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_8da72_row11_col0" class="data row11 col0" >0.0001</td>
#       <td id="T_8da72_row11_col1" class="data row11 col1" >0.0268</td>
#       <td id="T_8da72_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_8da72_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_8da72_row11_col4" class="data row11 col4" >0.0000</td>
#       <td id="T_8da72_row11_col5" class="data row11 col5" >0.0000</td>
#       <td id="T_8da72_row11_col6" class="data row11 col6" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_lgbm = tune_model(lgbm)
# Out:
# <style type="text/css">
# #T_526e9_row10_col0, #T_526e9_row10_col1, #T_526e9_row10_col2, #T_526e9_row10_col3, #T_526e9_row10_col4, #T_526e9_row10_col5, #T_526e9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_526e9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_526e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_526e9_row0_col0" class="data row0 col0" >0.9982</td>
#       <td id="T_526e9_row0_col1" class="data row0 col1" >0.9963</td>
#       <td id="T_526e9_row0_col2" class="data row0 col2" >0.9630</td>
#       <td id="T_526e9_row0_col3" class="data row0 col3" >0.9512</td>
#       <td id="T_526e9_row0_col4" class="data row0 col4" >0.9571</td>
#       <td id="T_526e9_row0_col5" class="data row0 col5" >0.9561</td>
#       <td id="T_526e9_row0_col6" class="data row0 col6" >0.9562</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_526e9_row1_col0" class="data row1 col0" >0.9964</td>
#       <td id="T_526e9_row1_col1" class="data row1 col1" >0.9987</td>
#       <td id="T_526e9_row1_col2" class="data row1 col2" >0.8765</td>
#       <td id="T_526e9_row1_col3" class="data row1 col3" >0.9467</td>
#       <td id="T_526e9_row1_col4" class="data row1 col4" >0.9103</td>
#       <td id="T_526e9_row1_col5" class="data row1 col5" >0.9084</td>
#       <td id="T_526e9_row1_col6" class="data row1 col6" >0.9091</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_526e9_row2_col0" class="data row2 col0" >0.9949</td>
#       <td id="T_526e9_row2_col1" class="data row2 col1" >0.9949</td>
#       <td id="T_526e9_row2_col2" class="data row2 col2" >0.8148</td>
#       <td id="T_526e9_row2_col3" class="data row2 col3" >0.9296</td>
#       <td id="T_526e9_row2_col4" class="data row2 col4" >0.8684</td>
#       <td id="T_526e9_row2_col5" class="data row2 col5" >0.8658</td>
#       <td id="T_526e9_row2_col6" class="data row2 col6" >0.8678</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_526e9_row3_col0" class="data row3 col0" >0.9959</td>
#       <td id="T_526e9_row3_col1" class="data row3 col1" >0.9970</td>
#       <td id="T_526e9_row3_col2" class="data row3 col2" >0.8500</td>
#       <td id="T_526e9_row3_col3" class="data row3 col3" >0.9444</td>
#       <td id="T_526e9_row3_col4" class="data row3 col4" >0.8947</td>
#       <td id="T_526e9_row3_col5" class="data row3 col5" >0.8926</td>
#       <td id="T_526e9_row3_col6" class="data row3 col6" >0.8939</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_526e9_row4_col0" class="data row4 col0" >0.9949</td>
#       <td id="T_526e9_row4_col1" class="data row4 col1" >0.9865</td>
#       <td id="T_526e9_row4_col2" class="data row4 col2" >0.7875</td>
#       <td id="T_526e9_row4_col3" class="data row4 col3" >0.9545</td>
#       <td id="T_526e9_row4_col4" class="data row4 col4" >0.8630</td>
#       <td id="T_526e9_row4_col5" class="data row4 col5" >0.8604</td>
#       <td id="T_526e9_row4_col6" class="data row4 col6" >0.8646</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_526e9_row5_col0" class="data row5 col0" >0.9951</td>
#       <td id="T_526e9_row5_col1" class="data row5 col1" >0.9936</td>
#       <td id="T_526e9_row5_col2" class="data row5 col2" >0.8500</td>
#       <td id="T_526e9_row5_col3" class="data row5 col3" >0.9067</td>
#       <td id="T_526e9_row5_col4" class="data row5 col4" >0.8774</td>
#       <td id="T_526e9_row5_col5" class="data row5 col5" >0.8749</td>
#       <td id="T_526e9_row5_col6" class="data row5 col6" >0.8754</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_526e9_row6_col0" class="data row6 col0" >0.9979</td>
#       <td id="T_526e9_row6_col1" class="data row6 col1" >0.9995</td>
#       <td id="T_526e9_row6_col2" class="data row6 col2" >0.9250</td>
#       <td id="T_526e9_row6_col3" class="data row6 col3" >0.9737</td>
#       <td id="T_526e9_row6_col4" class="data row6 col4" >0.9487</td>
#       <td id="T_526e9_row6_col5" class="data row6 col5" >0.9477</td>
#       <td id="T_526e9_row6_col6" class="data row6 col6" >0.9480</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_526e9_row7_col0" class="data row7 col0" >0.9959</td>
#       <td id="T_526e9_row7_col1" class="data row7 col1" >0.9913</td>
#       <td id="T_526e9_row7_col2" class="data row7 col2" >0.8875</td>
#       <td id="T_526e9_row7_col3" class="data row7 col3" >0.9103</td>
#       <td id="T_526e9_row7_col4" class="data row7 col4" >0.8987</td>
#       <td id="T_526e9_row7_col5" class="data row7 col5" >0.8966</td>
#       <td id="T_526e9_row7_col6" class="data row7 col6" >0.8967</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_526e9_row8_col0" class="data row8 col0" >0.9972</td>
#       <td id="T_526e9_row8_col1" class="data row8 col1" >0.9992</td>
#       <td id="T_526e9_row8_col2" class="data row8 col2" >0.8750</td>
#       <td id="T_526e9_row8_col3" class="data row8 col3" >0.9859</td>
#       <td id="T_526e9_row8_col4" class="data row8 col4" >0.9272</td>
#       <td id="T_526e9_row8_col5" class="data row8 col5" >0.9257</td>
#       <td id="T_526e9_row8_col6" class="data row8 col6" >0.9274</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_526e9_row9_col0" class="data row9 col0" >0.9969</td>
#       <td id="T_526e9_row9_col1" class="data row9 col1" >0.9997</td>
#       <td id="T_526e9_row9_col2" class="data row9 col2" >0.9012</td>
#       <td id="T_526e9_row9_col3" class="data row9 col3" >0.9481</td>
#       <td id="T_526e9_row9_col4" class="data row9 col4" >0.9241</td>
#       <td id="T_526e9_row9_col5" class="data row9 col5" >0.9225</td>
#       <td id="T_526e9_row9_col6" class="data row9 col6" >0.9228</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_526e9_row10_col0" class="data row10 col0" >0.9963</td>
#       <td id="T_526e9_row10_col1" class="data row10 col1" >0.9957</td>
#       <td id="T_526e9_row10_col2" class="data row10 col2" >0.8731</td>
#       <td id="T_526e9_row10_col3" class="data row10 col3" >0.9451</td>
#       <td id="T_526e9_row10_col4" class="data row10 col4" >0.9070</td>
#       <td id="T_526e9_row10_col5" class="data row10 col5" >0.9051</td>
#       <td id="T_526e9_row10_col6" class="data row10 col6" >0.9062</td>
#     </tr>
#     <tr>
#       <th id="T_526e9_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_526e9_row11_col0" class="data row11 col0" >0.0012</td>
#       <td id="T_526e9_row11_col1" class="data row11 col1" >0.0040</td>
#       <td id="T_526e9_row11_col2" class="data row11 col2" >0.0486</td>
#       <td id="T_526e9_row11_col3" class="data row11 col3" >0.0236</td>
#       <td id="T_526e9_row11_col4" class="data row11 col4" >0.0308</td>
#       <td id="T_526e9_row11_col5" class="data row11 col5" >0.0314</td>
#       <td id="T_526e9_row11_col6" class="data row11 col6" >0.0306</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.5 Evaluating models
#
# The `evaluate_model()` function displays a user interface for all the available plots for a given model. Let's see the performance for each of the models.

# %%
evaluate_model(tuned_dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(tuned_et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(tuned_lgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### 2.6 Predict on test/hold-out sample
#
# We perform one final check by predicting the test/hold-out set before we finalize the model. We saw earlier in section 2.1, we have 16,695 samples for the test data:
# __Transformed Test Set: (16695, 491)__

# %%
predict_model(tuned_dt);
# Out:
# <style type="text/css">
# </style>
# <table id="T_badc1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_badc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_badc1_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_badc1_row0_col1" class="data row0 col1" >0.9887</td>
#       <td id="T_badc1_row0_col2" class="data row0 col2" >0.9341</td>
#       <td id="T_badc1_row0_col3" class="data row0 col3" >0.6532</td>
#       <td id="T_badc1_row0_col4" class="data row0 col4" >0.7687</td>
#       <td id="T_badc1_row0_col5" class="data row0 col5" >0.7062</td>
#       <td id="T_badc1_row0_col6" class="data row0 col6" >0.7005</td>
#       <td id="T_badc1_row0_col7" class="data row0 col7" >0.7030</td>
#     </tr>
#   </tbody>
# </table>

# %%
predict_model(tuned_et);
# Out:
# <style type="text/css">
# </style>
# <table id="T_4cbbb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cbbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4cbbb_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_4cbbb_row0_col1" class="data row0 col1" >0.9793</td>
#       <td id="T_4cbbb_row0_col2" class="data row0 col2" >0.9037</td>
#       <td id="T_4cbbb_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_4cbbb_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_4cbbb_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_4cbbb_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_4cbbb_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
predict_model(tuned_lgbm);
# Out:
# <style type="text/css">
# </style>
# <table id="T_70034_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70034_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70034_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_70034_row0_col1" class="data row0 col1" >0.9956</td>
#       <td id="T_70034_row0_col2" class="data row0 col2" >0.9958</td>
#       <td id="T_70034_row0_col3" class="data row0 col3" >0.9220</td>
#       <td id="T_70034_row0_col4" class="data row0 col4" >0.8716</td>
#       <td id="T_70034_row0_col5" class="data row0 col5" >0.8961</td>
#       <td id="T_70034_row0_col6" class="data row0 col6" >0.8938</td>
#       <td id="T_70034_row0_col7" class="data row0 col7" >0.8942</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From the evaluation, we see that for the Extra Trees Classifier, the recall, precision and other metrics becomes 0. It also scores poorly for the AUC.
# We can probably drop the model from our evaluation.

# %% [markdown]
# ### 2.7 Finalize model for deployment
#
# Lastly, we proceed to train the model on the complete dataset with the `finalize_model()`. This should lead to the best model for use in making prediction on new and unseen data.

# %%
final_dt = finalize_model(tuned_dt)

# %%
final_et = finalize_model(tuned_et)

# %%
final_lgbm = finalize_model(tuned_lgbm)

# %%
print(final_dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=2, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0002, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=7679, splitter='best')

# %%
print(final_lgbm)
# Out:
# LGBMClassifier(bagging_fraction=0.4, bagging_freq=3, boosting_type='gbdt',
#                class_weight=None, colsample_bytree=1.0, feature_fraction=0.8,
#                importance_type='split', learning_rate=0.15, max_depth=-1,
#                min_child_samples=51, min_child_weight=0.001, min_split_gain=0.5,
#                n_estimators=250, n_jobs=-1, num_leaves=6, objective=None,
#                random_state=7679, reg_alpha=0.1, reg_lambda=0.005,
#                silent='warn', subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
print(final_et)
# Out:
# ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                      criterion='gini', max_depth=8, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.001, min_impurity_split=None,
#                      min_samples_leaf=6, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=250, n_jobs=-1,
#                      oob_score=False, random_state=7679, verbose=0,
#                      warm_start=False)

# %% [markdown]
# ### 2.8 Predict on unseen data
#
# We have previously used June data for ML modelling and put aside the July and August data in section 1.2.2.
# Now, we will use the unseen July and Aug data to test out the finalized model.
#
# #### 2.8.1 Decision Tree Classifier

# %%
prediction_output_col = ["trans_num", "Label", "Score"]

# %% [markdown]
# `Label` and `Score` columns are added onto the data_unseen set:
# - Label is the prediction
# - score is the probability of the prediction.

# %%
unseen_predictions = predict_model(final_dt, data=data_unseen)
unseen_predictions.head()
# Out:
#         category     amt  is_fraud  merchant_id gender  \
# 0   shopping_pos   14.11         0        81458      F
# 1    grocery_pos   75.52         0       490762      M
# 2    grocery_pos  136.23         0       635517      F
# 3  gas_transport   66.94         0        19638      F
# 4  entertainment  116.85         0        23622      M
#
#                          street              city state    zip  city_pop  ...  \
# 0   7820 Wilson Tunnel Apt. 795           Andrews    SC  29510     11060  ...
# 1          2137 Serrano Station  North Charleston    SC  29420     71702  ...
# 2           4656 Karen Parkways              Elmo    MT  59915       403  ...
# 3          74769 Anderson Plain           Oaktown    IN  47561      1588  ...
# 4  318 Brenda Terrace Suite 001           Beverly    WV  26253      3490  ...
#
#   txn_during_night  trans_weekend  nb_txns_1_days  avg_txns_amt_1_days  \
# 0                1              0             1.0                14.11
# 1                1              0             1.0                75.52
# 2                1              0             1.0               136.23
# 3                1              0             1.0                66.94
# 4                1              0             1.0               116.85
#
#    nb_txns_7_days  avg_txns_amt_7_days  nb_txns_30_days  avg_txns_amt_30_days  \
# 0            22.0            62.525455             33.0             55.510909
# 1            27.0            50.487407             69.0             73.280870
# 2            34.0            88.363529            127.0             69.842756
# 3            10.0            28.290000             60.0             30.620000
# 4            19.0            66.212105             92.0             65.748152
#
#    Label   Score
# 0      0  0.9976
# 1      0  0.9976
# 2      0  0.9976
# 3      0  0.9976
# 4      0  0.9976
#
# [5 rows x 23 columns]

# %% [markdown]
# It's nice that the predicted results are concatenated to the original dataset while all the transformations are automatically performed in the background.
#
# However, in section 1.2.3, we have selected only the features that we needed for the ML because we have a lot of features that we decided not necessary.
# Hence, we will do another merge back to the original data frame as we needed the `trans_num` for our use in atoti later on.

# %%
july_aug_prediction_dt = july_aug_data.merge(unseen_predictions)
july_aug_prediction_dt.head(3)
# Out:
#            ssn            cc_num      acct_num                        profile  \
# 0  547-69-7793  6534665167391525  693931531856  adults_50up_female_urban.json
# 1  191-61-6759  4166219838226478  181679512065    adults_2550_male_urban.json
# 2  027-46-7326  3513900304593051  920573624386  adults_50up_female_rural.json
#
#                           trans_num trans_date trans_time   unix_time  \
# 0  e14e1a05c8da5e3f3da457e6eb84d825 2021-07-01   00:00:18  1625097618
# 1  a3c0100cb4cfb7a5c4ffc90faaf7a6d8 2021-07-01   00:01:15  1625097675
# 2  9952d8bafe837216db5134d988d5144a 2021-07-01   00:02:12  1625097732
#
#        category     amt  ...  txn_during_night trans_weekend  nb_txns_1_days  \
# 0  shopping_pos   14.11  ...                 1             0             1.0
# 1   grocery_pos   75.52  ...                 1             0             1.0
# 2   grocery_pos  136.23  ...                 1             0             1.0
#
#    avg_txns_amt_1_days  nb_txns_7_days avg_txns_amt_7_days nb_txns_30_days  \
# 0                14.11            22.0           62.525455            33.0
# 1                75.52            27.0           50.487407            69.0
# 2               136.23            34.0           88.363529           127.0
#
#   avg_txns_amt_30_days Label   Score
# 0            55.510909     0  0.9976
# 1            73.280870     0  0.9976
# 2            69.842756     0  0.9976
#
# [3 rows x 39 columns]

# %% [markdown]
# This step is purely to output the prediction for loading into atoti. We will use atoti to gather some insights on the impact of the prediction on the various business metrics.

# %%
july_aug_prediction_dt[prediction_output_col].to_csv(
    f"{data_path}/july_aug_prediction_full_dt.csv", index=False
)

# %% [markdown]
# #### 2.8.2 Extra Trees Classifier
#
# For completeness, we will see the performance of this model despite its poor performance during the training.

# %%
unseen_predictions_et = predict_model(final_et, data=data_unseen)
unseen_predictions_et.head()
# Out:
#         category     amt  is_fraud  merchant_id gender  \
# 0   shopping_pos   14.11         0        81458      F
# 1    grocery_pos   75.52         0       490762      M
# 2    grocery_pos  136.23         0       635517      F
# 3  gas_transport   66.94         0        19638      F
# 4  entertainment  116.85         0        23622      M
#
#                          street              city state    zip  city_pop  ...  \
# 0   7820 Wilson Tunnel Apt. 795           Andrews    SC  29510     11060  ...
# 1          2137 Serrano Station  North Charleston    SC  29420     71702  ...
# 2           4656 Karen Parkways              Elmo    MT  59915       403  ...
# 3          74769 Anderson Plain           Oaktown    IN  47561      1588  ...
# 4  318 Brenda Terrace Suite 001           Beverly    WV  26253      3490  ...
#
#   txn_during_night  trans_weekend  nb_txns_1_days  avg_txns_amt_1_days  \
# 0                1              0             1.0                14.11
# 1                1              0             1.0                75.52
# 2                1              0             1.0               136.23
# 3                1              0             1.0                66.94
# 4                1              0             1.0               116.85
#
#    nb_txns_7_days  avg_txns_amt_7_days  nb_txns_30_days  avg_txns_amt_30_days  \
# 0            22.0            62.525455             33.0             55.510909
# 1            27.0            50.487407             69.0             73.280870
# 2            34.0            88.363529            127.0             69.842756
# 3            10.0            28.290000             60.0             30.620000
# 4            19.0            66.212105             92.0             65.748152
#
#    Label   Score
# 0      0  0.9781
# 1      0  0.9781
# 2      0  0.9781
# 3      0  0.9781
# 4      0  0.9781
#
# [5 rows x 23 columns]

# %%
july_aug_prediction_et = july_aug_data.merge(unseen_predictions_et)
july_aug_prediction_et.head(3)
# Out:
#            ssn            cc_num      acct_num                        profile  \
# 0  547-69-7793  6534665167391525  693931531856  adults_50up_female_urban.json
# 1  191-61-6759  4166219838226478  181679512065    adults_2550_male_urban.json
# 2  027-46-7326  3513900304593051  920573624386  adults_50up_female_rural.json
#
#                           trans_num trans_date trans_time   unix_time  \
# 0  e14e1a05c8da5e3f3da457e6eb84d825 2021-07-01   00:00:18  1625097618
# 1  a3c0100cb4cfb7a5c4ffc90faaf7a6d8 2021-07-01   00:01:15  1625097675
# 2  9952d8bafe837216db5134d988d5144a 2021-07-01   00:02:12  1625097732
#
#        category     amt  ...  txn_during_night trans_weekend  nb_txns_1_days  \
# 0  shopping_pos   14.11  ...                 1             0             1.0
# 1   grocery_pos   75.52  ...                 1             0             1.0
# 2   grocery_pos  136.23  ...                 1             0             1.0
#
#    avg_txns_amt_1_days  nb_txns_7_days avg_txns_amt_7_days nb_txns_30_days  \
# 0                14.11            22.0           62.525455            33.0
# 1                75.52            27.0           50.487407            69.0
# 2               136.23            34.0           88.363529           127.0
#
#   avg_txns_amt_30_days Label   Score
# 0            55.510909     0  0.9781
# 1            73.280870     0  0.9781
# 2            69.842756     0  0.9781
#
# [3 rows x 39 columns]

# %%
july_aug_prediction_et[prediction_output_col].to_csv(
    f"{data_path}/july_aug_prediction_full_et.csv", index=False
)

# %% [markdown]
# #### 2.8.3 Light Gradient Boosting Machine
#
# During the model compare, LGBM has the highest AUC. Let's see if it do as well for the unseen data prediction.

# %%
unseen_predictions_lgbm = predict_model(final_lgbm, data=data_unseen)
unseen_predictions_lgbm.head()
# Out:
#         category     amt  is_fraud  merchant_id gender  \
# 0   shopping_pos   14.11         0        81458      F
# 1    grocery_pos   75.52         0       490762      M
# 2    grocery_pos  136.23         0       635517      F
# 3  gas_transport   66.94         0        19638      F
# 4  entertainment  116.85         0        23622      M
#
#                          street              city state    zip  city_pop  ...  \
# 0   7820 Wilson Tunnel Apt. 795           Andrews    SC  29510     11060  ...
# 1          2137 Serrano Station  North Charleston    SC  29420     71702  ...
# 2           4656 Karen Parkways              Elmo    MT  59915       403  ...
# 3          74769 Anderson Plain           Oaktown    IN  47561      1588  ...
# 4  318 Brenda Terrace Suite 001           Beverly    WV  26253      3490  ...
#
#   txn_during_night  trans_weekend  nb_txns_1_days  avg_txns_amt_1_days  \
# 0                1              0             1.0                14.11
# 1                1              0             1.0                75.52
# 2                1              0             1.0               136.23
# 3                1              0             1.0                66.94
# 4                1              0             1.0               116.85
#
#    nb_txns_7_days  avg_txns_amt_7_days  nb_txns_30_days  avg_txns_amt_30_days  \
# 0            22.0            62.525455             33.0             55.510909
# 1            27.0            50.487407             69.0             73.280870
# 2            34.0            88.363529            127.0             69.842756
# 3            10.0            28.290000             60.0             30.620000
# 4            19.0            66.212105             92.0             65.748152
#
#    Label   Score
# 0      0  0.9999
# 1      0  0.9998
# 2      0  1.0000
# 3      0  0.9999
# 4      0  0.9998
#
# [5 rows x 23 columns]

# %%
july_aug_prediction_lgbm = july_aug_data.merge(unseen_predictions_lgbm)
july_aug_prediction_lgbm.head(3)
# Out:
#            ssn            cc_num      acct_num                        profile  \
# 0  547-69-7793  6534665167391525  693931531856  adults_50up_female_urban.json
# 1  191-61-6759  4166219838226478  181679512065    adults_2550_male_urban.json
# 2  027-46-7326  3513900304593051  920573624386  adults_50up_female_rural.json
#
#                           trans_num trans_date trans_time   unix_time  \
# 0  e14e1a05c8da5e3f3da457e6eb84d825 2021-07-01   00:00:18  1625097618
# 1  a3c0100cb4cfb7a5c4ffc90faaf7a6d8 2021-07-01   00:01:15  1625097675
# 2  9952d8bafe837216db5134d988d5144a 2021-07-01   00:02:12  1625097732
#
#        category     amt  ...  txn_during_night trans_weekend  nb_txns_1_days  \
# 0  shopping_pos   14.11  ...                 1             0             1.0
# 1   grocery_pos   75.52  ...                 1             0             1.0
# 2   grocery_pos  136.23  ...                 1             0             1.0
#
#    avg_txns_amt_1_days  nb_txns_7_days avg_txns_amt_7_days nb_txns_30_days  \
# 0                14.11            22.0           62.525455            33.0
# 1                75.52            27.0           50.487407            69.0
# 2               136.23            34.0           88.363529           127.0
#
#   avg_txns_amt_30_days Label   Score
# 0            55.510909     0  0.9999
# 1            73.280870     0  0.9998
# 2            69.842756     0  1.0000
#
# [3 rows x 39 columns]

# %%
july_aug_prediction_lgbm[prediction_output_col].to_csv(
    f"{data_path}/july_aug_prediction_full_lgbm.csv", index=False
)

# %% [markdown]
# We will use the `check_metric` function from the `pycaret.utils` to get the AUC of the run. We can change and compare the metric to recall if preferred.
# It seems that LGBM still has the best AUC. But generally, the AUC scores are lower than what we have on the predict_mode stage in section 2.5.
#
# We shall see if the same holds true when we perform real-time streaming and ML evaluation in atoti.

# %%
from pycaret.utils import check_metric

check_metric(unseen_predictions["is_fraud"], unseen_predictions["Label"], metric="AUC")
# Out:
# 0.8413

# %%
check_metric(
    unseen_predictions_et["is_fraud"], unseen_predictions_et["Label"], metric="AUC"
)
# Out:
# 0.5

# %%
check_metric(
    unseen_predictions_lgbm["is_fraud"], unseen_predictions_lgbm["Label"], metric="AUC"
)
# Out:
# 0.9306

# %% [markdown]
# ### 2.9 Save trained model for real-time fraud detection with atoti
#
# It takes a long time to train the models. Hence, it's great that we can save and use the model without having to repeat these all the time.

# %%
save_model(final_dt, "Final DT Model 20211130")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['zip',
#                                                              'merchant_id'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['txn_during_night',
#                                                            'trans_weekend'],
#                                        target='is_fraud', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_c...
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='entropy', max_depth=2,
#                                          max_features=1.0, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0002,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=3, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          presort='deprecated', random_state=7679,
#                                          splitter='best')]],
#           verbose=False),
#  'Final DT Model 20211130.pkl')

# %%
save_model(final_et, "Final ET Model 20211130")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['zip',
#                                                              'merchant_id'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['txn_during_night',
#                                                            'trans_weekend'],
#                                        target='is_fraud', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_c...
#                   ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0,
#                                        class_weight={}, criterion='gini',
#                                        max_depth=8, max_features='sqrt',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.001,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=6, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=250, n_jobs=-1,
#                                        oob_score=False, random_state=7679,
#                                        verbose=0, warm_start=False)]],
#           verbose=False),
#  'Final ET Model 20211130.pkl')

# %%
save_model(final_lgbm, "Final LGBM Model 20211130")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['zip',
#                                                              'merchant_id'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['txn_during_night',
#                                                            'trans_weekend'],
#                                        target='is_fraud', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_c...
#                                  colsample_bytree=1.0, feature_fraction=0.8,
#                                  importance_type='split', learning_rate=0.15,
#                                  max_depth=-1, min_child_samples=51,
#                                  min_child_weight=0.001, min_split_gain=0.5,
#                                  n_estimators=250, n_jobs=-1, num_leaves=6,
#                                  objective=None, random_state=7679,
#                                  reg_alpha=0.1, reg_lambda=0.005, silent='warn',
#                                  subsample=1.0, subsample_for_bin=200000,
#                                  subsample_freq=0)]],
#           verbose=False),
#  'Final LGBM Model 20211130.pkl')
