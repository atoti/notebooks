# %%
# ! pip install faker

# %% [markdown]
# # Generating synthetic credit card transactions for fraud detection with AutoML
#
# In this notebook, we will be using the Synthetic Credit Card Transaction Generator used in the Sparkov program to generate:
# - customer data file
# - transactions utilizing prior customer file
#
# This is adapted from the GitHub repository [Sparkov_Data_Generation](https://github.com/namebrandon/Sparkov_Data_Generation).

# %%
import math
import os
import random
from datetime import date, datetime, timedelta

import faker
import pandas as pd
from faker import Faker

from sparkov_data_generation.datagen_customer import generate_customers
from sparkov_data_generation.datagen_transaction import generate_transactions

# %% [markdown]
# ## 1 User Profile
#
# The profiles comprises of:
# - Fraudulent / Non-fraudulent
# - Male / Female
# - Age groups ranging from:
#     - <= 25
#     - 25 - 50
#     - \>= 50
# - Geographical location
#     - urban
#     - rural
# - Average transaction a day
# - Weighted spending habits across:
#     - the week
#     - time of the year such as holiday or seasons
#     - across each quarter of the year
#     - time of the day (AM/PM)
# - Weighted spending across various expenditure categories
#
# The profiles can be found under the directory __sparkov_data_generation/profiles__.

# %%
profiles = [
    p
    for p in os.listdir("sparkov_data_generation/profiles")
    if p.startswith("adults") or (p.startswith("young"))
]
profiles
# Out:
# ['adults_2550_female_rural.json',
#  'adults_2550_female_urban.json',
#  'adults_2550_male_rural.json',
#  'adults_2550_male_urban.json',
#  'adults_50up_female_rural.json',
#  'adults_50up_female_urban.json',
#  'adults_50up_male_rural.json',
#  'adults_50up_male_urban.json',
#  'young_adults_female_rural.json',
#  'young_adults_female_urban.json',
#  'young_adults_male_rural.json',
#  'young_adults_male_urban.json']

# %% [markdown]
# ## 2 Instantiating variables

# %%
# Faker seed number to ensure constant customer list
seed_num = 4444

# initial number of customers
initial_cust_base_size = 500

# generate 4 months worth of data
start_dt = datetime.strptime("2021-06-01", "%Y-%m-%d")
end_dt = datetime.strptime("2021-10-30", "%Y-%m-%d")

cust_list = pd.DataFrame()
# txn_df = pd.DataFrame()

# output directory and file naming conventions
data_base_dir = "output/"
customer_output_file = f"{data_base_dir}/customers_list.csv"
txn_output_file = "_txn.csv"

# create output directory if not existing
os.makedirs(data_base_dir, exist_ok=True)

# %% [markdown]
# ## 3 Simulated transactions
#
# The program uses [Faker](https://faker.readthedocs.io/en/master/) to generate:
# - customer details
# - transaction numbers
# - credit card number
# - merchant transaction locations
#
# In order to generate the same list of customers, we will use a fixed seed number.

# %%
fake = Faker()
Faker.seed(seed_num)

# %% [markdown]
# On the start date, we create 500 customers and their transactions from the start to the end date. For each of the subsquent dates until the end date, the customer base increase between 1% to 3%. The customers list and their transaction history are saved in the "output" folder.

# %%
for dt in (start_dt + timedelta(n) for n in range(int((end_dt - start_dt).days))):
    print("Date", dt)

    if dt == start_dt:
        num_new_customers = initial_cust_base_size
    else:
        increment = random.uniform(0.01, 0.03)
        num_new_customers = math.ceil(len(cust_list) * increment)

    print("Number of customers newly onboard: ", num_new_customers)

    new_cust_list = generate_customers(
        fake, num_new_customers, "sparkov_data_generation/profiles/main_config.json"
    )
    cust_list = cust_list.append(new_cust_list, ignore_index=True)
    print("Total customer: ", len(cust_list))
    new_cust_list.to_csv(
        customer_output_file,
        mode="a",
        header=not os.path.exists(customer_output_file),
        index=False,
    )

    for p in profiles:
        # generate txns for the new customers from current date to the end date
        new_cust_txn_df = generate_transactions(new_cust_list, p, dt, end_dt)
        print(f"Number of transaction ({p}): ", len(new_cust_txn_df))
        new_cust_txn_df.to_csv(
            f"{data_base_dir}{p}{txn_output_file}",
            mode="a",
            header=not os.path.exists(f"{data_base_dir}{p}{txn_output_file}"),
            index=False,
        )
# Out:
# Date 2021-06-01 00:00:00
# Number of customers newly onboard:  500
# Total customer:  500
# Number of transaction (adults_2550_female_rural.json):  24166
# Number of transaction (adults_2550_female_urban.json):  27872
# Number of transaction (adults_2550_male_rural.json):  18578
# Number of transaction (adults_2550_male_urban.json):  24987
# Number of transaction (adults_50up_female_rural.json):  20914
# Number of transaction (adults_50up_female_urban.json):  12861
# Number of transaction (adults_50up_male_rural.json):  22518
# Number of transaction (adults_50up_male_urban.json):  18419
# Number of transaction (young_adults_female_rural.json):  3072
# Number of transaction (young_adults_female_urban.json):  4434
# Number of transaction (young_adults_male_rural.json):  4543
# Number of transaction (young_adults_male_urban.json):  12947
# Date 2021-06-02 00:00:00
# Number of customers newly onboard:  7
# Total customer:  507
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  756
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  303
# Number of transaction (adults_50up_female_urban.json):  311
# Number of transaction (adults_50up_male_rural.json):  759
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-03 00:00:00
# Number of customers newly onboard:  15
# Total customer:  522
# Number of transaction (adults_2550_female_rural.json):  607
# Number of transaction (adults_2550_female_urban.json):  1798
# Number of transaction (adults_2550_male_rural.json):  598
# Number of transaction (adults_2550_male_urban.json):  305
# Number of transaction (adults_50up_female_rural.json):  594
# Number of transaction (adults_50up_female_urban.json):  456
# Number of transaction (adults_50up_male_rural.json):  1797
# Number of transaction (adults_50up_male_urban.json):  454
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-04 00:00:00
# Number of customers newly onboard:  8
# Total customer:  530
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  908
# Number of transaction (adults_2550_male_rural.json):  452
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  624
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  307
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  160
# Date 2021-06-05 00:00:00
# Number of customers newly onboard:  6
# Total customer:  536
# Number of transaction (adults_2550_female_rural.json):  444
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  1039
# Number of transaction (adults_50up_female_rural.json):  296
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  154
# Number of transaction (young_adults_male_urban.json):  592
# Date 2021-06-06 00:00:00
# Number of customers newly onboard:  7
# Total customer:  543
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  882
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  585
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  152
# Number of transaction (adults_50up_male_rural.json):  578
# Number of transaction (adults_50up_male_urban.json):  7
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  586
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-07 00:00:00
# Number of customers newly onboard:  15
# Total customer:  558
# Number of transaction (adults_2550_female_rural.json):  158
# Number of transaction (adults_2550_female_urban.json):  873
# Number of transaction (adults_2550_male_rural.json):  588
# Number of transaction (adults_2550_male_urban.json):  294
# Number of transaction (adults_50up_female_rural.json):  1024
# Number of transaction (adults_50up_female_urban.json):  313
# Number of transaction (adults_50up_male_rural.json):  594
# Number of transaction (adults_50up_male_urban.json):  591
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-08 00:00:00
# Number of customers newly onboard:  8
# Total customer:  566
# Number of transaction (adults_2550_female_rural.json):  580
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  1019
# Number of transaction (adults_50up_female_rural.json):  430
# Number of transaction (adults_50up_female_urban.json):  295
# Number of transaction (adults_50up_male_rural.json):  291
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  433
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-09 00:00:00
# Number of customers newly onboard:  12
# Total customer:  578
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  1147
# Number of transaction (adults_50up_female_rural.json):  721
# Number of transaction (adults_50up_female_urban.json):  586
# Number of transaction (adults_50up_male_rural.json):  298
# Number of transaction (adults_50up_male_urban.json):  1163
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  715
# Date 2021-06-10 00:00:00
# Number of customers newly onboard:  15
# Total customer:  593
# Number of transaction (adults_2550_female_rural.json):  853
# Number of transaction (adults_2550_female_urban.json):  843
# Number of transaction (adults_2550_male_rural.json):  1305
# Number of transaction (adults_2550_male_urban.json):  430
# Number of transaction (adults_50up_female_rural.json):  291
# Number of transaction (adults_50up_female_urban.json):  861
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  305
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-11 00:00:00
# Number of customers newly onboard:  11
# Total customer:  604
# Number of transaction (adults_2550_female_rural.json):  1003
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  570
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  150
# Number of transaction (adults_50up_male_rural.json):  1135
# Number of transaction (adults_50up_male_urban.json):  11
# Number of transaction (young_adults_female_rural.json):  148
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  709
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-12 00:00:00
# Number of customers newly onboard:  15
# Total customer:  619
# Number of transaction (adults_2550_female_rural.json):  284
# Number of transaction (adults_2550_female_urban.json):  851
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  432
# Number of transaction (adults_50up_female_rural.json):  2523
# Number of transaction (adults_50up_female_urban.json):  701
# Number of transaction (adults_50up_male_rural.json):  439
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  702
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-13 00:00:00
# Number of customers newly onboard:  17
# Total customer:  636
# Number of transaction (adults_2550_female_rural.json):  1664
# Number of transaction (adults_2550_female_urban.json):  698
# Number of transaction (adults_2550_male_rural.json):  852
# Number of transaction (adults_2550_male_urban.json):  985
# Number of transaction (adults_50up_female_rural.json):  411
# Number of transaction (adults_50up_female_urban.json):  983
# Number of transaction (adults_50up_male_rural.json):  146
# Number of transaction (adults_50up_male_urban.json):  1000
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-14 00:00:00
# Number of customers newly onboard:  12
# Total customer:  648
# Number of transaction (adults_2550_female_rural.json):  152
# Number of transaction (adults_2550_female_urban.json):  1504
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  683
# Number of transaction (adults_50up_female_rural.json):  419
# Number of transaction (adults_50up_female_urban.json):  415
# Number of transaction (adults_50up_male_rural.json):  701
# Number of transaction (adults_50up_male_urban.json):  834
# Number of transaction (young_adults_female_rural.json):  412
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  416
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-15 00:00:00
# Number of customers newly onboard:  14
# Total customer:  662
# Number of transaction (adults_2550_female_rural.json):  279
# Number of transaction (adults_2550_female_urban.json):  278
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  411
# Number of transaction (adults_50up_female_rural.json):  1101
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  1125
# Number of transaction (adults_50up_male_urban.json):  845
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  552
# Number of transaction (young_adults_male_urban.json):  421
# Date 2021-06-16 00:00:00
# Number of customers newly onboard:  18
# Total customer:  680
# Number of transaction (adults_2550_female_rural.json):  417
# Number of transaction (adults_2550_female_urban.json):  2040
# Number of transaction (adults_2550_male_rural.json):  553
# Number of transaction (adults_2550_male_urban.json):  1223
# Number of transaction (adults_50up_female_rural.json):  422
# Number of transaction (adults_50up_female_urban.json):  983
# Number of transaction (adults_50up_male_rural.json):  955
# Number of transaction (adults_50up_male_urban.json):  270
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  278
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-17 00:00:00
# Number of customers newly onboard:  7
# Total customer:  687
# Number of transaction (adults_2550_female_rural.json):  804
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  275
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  539
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  425
# Number of transaction (adults_50up_male_urban.json):  404
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  681
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-18 00:00:00
# Number of customers newly onboard:  21
# Total customer:  708
# Number of transaction (adults_2550_female_rural.json):  804
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  411
# Number of transaction (adults_2550_male_urban.json):  1222
# Number of transaction (adults_50up_female_rural.json):  816
# Number of transaction (adults_50up_female_urban.json):  549
# Number of transaction (adults_50up_male_rural.json):  677
# Number of transaction (adults_50up_male_urban.json):  955
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  540
# Date 2021-06-19 00:00:00
# Number of customers newly onboard:  14
# Total customer:  722
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  405
# Number of transaction (adults_2550_male_rural.json):  277
# Number of transaction (adults_2550_male_urban.json):  661
# Number of transaction (adults_50up_female_rural.json):  140
# Number of transaction (adults_50up_female_urban.json):  683
# Number of transaction (adults_50up_male_rural.json):  1359
# Number of transaction (adults_50up_male_urban.json):  401
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  9
# Date 2021-06-20 00:00:00
# Number of customers newly onboard:  14
# Total customer:  736
# Number of transaction (adults_2550_female_rural.json):  790
# Number of transaction (adults_2550_female_urban.json):  1851
# Number of transaction (adults_2550_male_rural.json):  404
# Number of transaction (adults_2550_male_urban.json):  1067
# Number of transaction (adults_50up_female_rural.json):  146
# Number of transaction (adults_50up_female_urban.json):  1072
# Number of transaction (adults_50up_male_rural.json):  139
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-21 00:00:00
# Number of customers newly onboard:  13
# Total customer:  749
# Number of transaction (adults_2550_female_rural.json):  266
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  543
# Number of transaction (adults_2550_male_urban.json):  1311
# Number of transaction (adults_50up_female_rural.json):  1715
# Number of transaction (adults_50up_female_urban.json):  267
# Number of transaction (adults_50up_male_rural.json):  141
# Number of transaction (adults_50up_male_urban.json):  12
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-22 00:00:00
# Number of customers newly onboard:  16
# Total customer:  765
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  1292
# Number of transaction (adults_2550_male_rural.json):  1050
# Number of transaction (adults_2550_male_urban.json):  657
# Number of transaction (adults_50up_female_rural.json):  406
# Number of transaction (adults_50up_female_urban.json):  797
# Number of transaction (adults_50up_male_rural.json):  130
# Number of transaction (adults_50up_male_urban.json):  15
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  142
# Date 2021-06-23 00:00:00
# Number of customers newly onboard:  18
# Total customer:  783
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  511
# Number of transaction (adults_2550_male_rural.json):  1184
# Number of transaction (adults_2550_male_urban.json):  1837
# Number of transaction (adults_50up_female_rural.json):  1068
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  398
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  137
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-24 00:00:00
# Number of customers newly onboard:  15
# Total customer:  798
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  257
# Number of transaction (adults_2550_male_rural.json):  917
# Number of transaction (adults_2550_male_urban.json):  260
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  919
# Number of transaction (adults_50up_male_rural.json):  135
# Number of transaction (adults_50up_male_urban.json):  390
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  1167
# Date 2021-06-25 00:00:00
# Number of customers newly onboard:  18
# Total customer:  816
# Number of transaction (adults_2550_female_rural.json):  269
# Number of transaction (adults_2550_female_urban.json):  625
# Number of transaction (adults_2550_male_rural.json):  387
# Number of transaction (adults_2550_male_urban.json):  1916
# Number of transaction (adults_50up_female_rural.json):  1022
# Number of transaction (adults_50up_female_urban.json):  134
# Number of transaction (adults_50up_male_rural.json):  1157
# Number of transaction (adults_50up_male_urban.json):  658
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  770
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-26 00:00:00
# Number of customers newly onboard:  15
# Total customer:  831
# Number of transaction (adults_2550_female_rural.json):  1407
# Number of transaction (adults_2550_female_urban.json):  753
# Number of transaction (adults_2550_male_rural.json):  1407
# Number of transaction (adults_2550_male_urban.json):  1275
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  134
# Number of transaction (adults_50up_male_rural.json):  499
# Number of transaction (adults_50up_male_urban.json):  131
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-27 00:00:00
# Number of customers newly onboard:  25
# Total customer:  856
# Number of transaction (adults_2550_female_rural.json):  1391
# Number of transaction (adults_2550_female_urban.json):  1261
# Number of transaction (adults_2550_male_rural.json):  1264
# Number of transaction (adults_2550_male_urban.json):  258
# Number of transaction (adults_50up_female_rural.json):  1153
# Number of transaction (adults_50up_female_urban.json):  255
# Number of transaction (adults_50up_male_rural.json):  267
# Number of transaction (adults_50up_male_urban.json):  760
# Number of transaction (young_adults_female_rural.json):  130
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  391
# Number of transaction (young_adults_male_urban.json):  506
# Date 2021-06-28 00:00:00
# Number of customers newly onboard:  10
# Total customer:  866
# Number of transaction (adults_2550_female_rural.json):  739
# Number of transaction (adults_2550_female_urban.json):  365
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  144
# Number of transaction (adults_50up_male_rural.json):  501
# Number of transaction (adults_50up_male_urban.json):  407
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  616
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-06-29 00:00:00
# Number of customers newly onboard:  12
# Total customer:  878
# Number of transaction (adults_2550_female_rural.json):  869
# Number of transaction (adults_2550_female_urban.json):  618
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  129
# Number of transaction (adults_50up_female_rural.json):  492
# Number of transaction (adults_50up_female_urban.json):  496
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  387
# Number of transaction (young_adults_female_rural.json):  16
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  621
# Date 2021-06-30 00:00:00
# Number of customers newly onboard:  22
# Total customer:  900
# Number of transaction (adults_2550_female_rural.json):  1492
# Number of transaction (adults_2550_female_urban.json):  594
# Number of transaction (adults_2550_male_rural.json):  487
# Number of transaction (adults_2550_male_urban.json):  1594
# Number of transaction (adults_50up_female_rural.json):  1492
# Number of transaction (adults_50up_female_urban.json):  641
# Number of transaction (adults_50up_male_rural.json):  759
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  253
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-01 00:00:00
# Number of customers newly onboard:  10
# Total customer:  910
# Number of transaction (adults_2550_female_rural.json):  496
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  856
# Number of transaction (adults_2550_male_urban.json):  245
# Number of transaction (adults_50up_female_rural.json):  0
# Number of transaction (adults_50up_female_urban.json):  19
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  127
# Number of transaction (young_adults_female_rural.json):  732
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  708
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-02 00:00:00
# Number of customers newly onboard:  24
# Total customer:  934
# Number of transaction (adults_2550_female_rural.json):  1087
# Number of transaction (adults_2550_female_urban.json):  963
# Number of transaction (adults_2550_male_rural.json):  133
# Number of transaction (adults_2550_male_urban.json):  1437
# Number of transaction (adults_50up_female_rural.json):  2893
# Number of transaction (adults_50up_female_urban.json):  740
# Number of transaction (adults_50up_male_rural.json):  379
# Number of transaction (adults_50up_male_urban.json):  365
# Number of transaction (young_adults_female_rural.json):  361
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  369
# Date 2021-07-03 00:00:00
# Number of customers newly onboard:  27
# Total customer:  961
# Number of transaction (adults_2550_female_rural.json):  717
# Number of transaction (adults_2550_female_urban.json):  594
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  1078
# Number of transaction (adults_50up_female_rural.json):  1573
# Number of transaction (adults_50up_female_urban.json):  1229
# Number of transaction (adults_50up_male_rural.json):  1102
# Number of transaction (adults_50up_male_urban.json):  269
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  240
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  486
# Date 2021-07-04 00:00:00
# Number of customers newly onboard:  16
# Total customer:  977
# Number of transaction (adults_2550_female_rural.json):  1309
# Number of transaction (adults_2550_female_urban.json):  1319
# Number of transaction (adults_2550_male_rural.json):  243
# Number of transaction (adults_2550_male_urban.json):  715
# Number of transaction (adults_50up_female_rural.json):  352
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  360
# Number of transaction (adults_50up_male_urban.json):  483
# Number of transaction (young_adults_female_rural.json):  714
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-05 00:00:00
# Number of customers newly onboard:  29
# Total customer:  1006
# Number of transaction (adults_2550_female_rural.json):  957
# Number of transaction (adults_2550_female_urban.json):  825
# Number of transaction (adults_2550_male_rural.json):  714
# Number of transaction (adults_2550_male_urban.json):  834
# Number of transaction (adults_50up_female_rural.json):  2117
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  1181
# Number of transaction (adults_50up_male_urban.json):  1431
# Number of transaction (young_adults_female_rural.json):  13
# Number of transaction (young_adults_female_urban.json):  130
# Number of transaction (young_adults_male_rural.json):  9
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-06 00:00:00
# Number of customers newly onboard:  29
# Total customer:  1035
# Number of transaction (adults_2550_female_rural.json):  578
# Number of transaction (adults_2550_female_urban.json):  1865
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  1205
# Number of transaction (adults_50up_female_urban.json):  489
# Number of transaction (adults_50up_male_rural.json):  1410
# Number of transaction (adults_50up_male_urban.json):  1434
# Number of transaction (young_adults_female_rural.json):  693
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  10
# Number of transaction (young_adults_male_urban.json):  1287
# Date 2021-07-07 00:00:00
# Number of customers newly onboard:  21
# Total customer:  1056
# Number of transaction (adults_2550_female_rural.json):  123
# Number of transaction (adults_2550_female_urban.json):  118
# Number of transaction (adults_2550_male_rural.json):  346
# Number of transaction (adults_2550_male_urban.json):  926
# Number of transaction (adults_50up_female_rural.json):  476
# Number of transaction (adults_50up_female_urban.json):  582
# Number of transaction (adults_50up_male_rural.json):  1044
# Number of transaction (adults_50up_male_urban.json):  939
# Number of transaction (young_adults_female_rural.json):  126
# Number of transaction (young_adults_female_urban.json):  689
# Number of transaction (young_adults_male_rural.json):  1509
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-08 00:00:00
# Number of customers newly onboard:  20
# Total customer:  1076
# Number of transaction (adults_2550_female_rural.json):  120
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  595
# Number of transaction (adults_2550_male_urban.json):  342
# Number of transaction (adults_50up_female_rural.json):  359
# Number of transaction (adults_50up_female_urban.json):  1075
# Number of transaction (adults_50up_male_rural.json):  578
# Number of transaction (adults_50up_male_urban.json):  569
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  698
# Number of transaction (young_adults_male_urban.json):  364
# Date 2021-07-09 00:00:00
# Number of customers newly onboard:  14
# Total customer:  1090
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  1492
# Number of transaction (adults_2550_male_rural.json):  345
# Number of transaction (adults_2550_male_urban.json):  789
# Number of transaction (adults_50up_female_rural.json):  908
# Number of transaction (adults_50up_female_urban.json):  339
# Number of transaction (adults_50up_male_rural.json):  235
# Number of transaction (adults_50up_male_urban.json):  232
# Number of transaction (young_adults_female_rural.json):  341
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-10 00:00:00
# Number of customers newly onboard:  27
# Total customer:  1117
# Number of transaction (adults_2550_female_rural.json):  1577
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  1838
# Number of transaction (adults_2550_male_urban.json):  790
# Number of transaction (adults_50up_female_rural.json):  2264
# Number of transaction (adults_50up_female_urban.json):  679
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  571
# Number of transaction (young_adults_female_rural.json):  580
# Number of transaction (young_adults_female_urban.json):  561
# Number of transaction (young_adults_male_rural.json):  443
# Number of transaction (young_adults_male_urban.json):  568
# Date 2021-07-11 00:00:00
# Number of customers newly onboard:  26
# Total customer:  1143
# Number of transaction (adults_2550_female_rural.json):  443
# Number of transaction (adults_2550_female_urban.json):  1673
# Number of transaction (adults_2550_male_rural.json):  570
# Number of transaction (adults_2550_male_urban.json):  335
# Number of transaction (adults_50up_female_rural.json):  1015
# Number of transaction (adults_50up_female_urban.json):  611
# Number of transaction (adults_50up_male_rural.json):  0
# Number of transaction (adults_50up_male_urban.json):  696
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  573
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  449
# Date 2021-07-12 00:00:00
# Number of customers newly onboard:  35
# Total customer:  1178
# Number of transaction (adults_2550_female_rural.json):  1109
# Number of transaction (adults_2550_female_urban.json):  1314
# Number of transaction (adults_2550_male_rural.json):  1479
# Number of transaction (adults_2550_male_urban.json):  238
# Number of transaction (adults_50up_female_rural.json):  345
# Number of transaction (adults_50up_female_urban.json):  457
# Number of transaction (adults_50up_male_rural.json):  1871
# Number of transaction (adults_50up_male_urban.json):  1455
# Number of transaction (young_adults_female_rural.json):  442
# Number of transaction (young_adults_female_urban.json):  11
# Number of transaction (young_adults_male_rural.json):  235
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-13 00:00:00
# Number of customers newly onboard:  16
# Total customer:  1194
# Number of transaction (adults_2550_female_rural.json):  1098
# Number of transaction (adults_2550_female_urban.json):  878
# Number of transaction (adults_2550_male_rural.json):  222
# Number of transaction (adults_2550_male_urban.json):  654
# Number of transaction (adults_50up_female_rural.json):  220
# Number of transaction (adults_50up_female_urban.json):  114
# Number of transaction (adults_50up_male_rural.json):  116
# Number of transaction (adults_50up_male_urban.json):  222
# Number of transaction (young_adults_female_rural.json):  225
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  444
# Number of transaction (young_adults_male_urban.json):  559
# Date 2021-07-14 00:00:00
# Number of customers newly onboard:  27
# Total customer:  1221
# Number of transaction (adults_2550_female_rural.json):  332
# Number of transaction (adults_2550_female_urban.json):  330
# Number of transaction (adults_2550_male_rural.json):  1629
# Number of transaction (adults_2550_male_urban.json):  778
# Number of transaction (adults_50up_female_rural.json):  553
# Number of transaction (adults_50up_female_urban.json):  336
# Number of transaction (adults_50up_male_rural.json):  1118
# Number of transaction (adults_50up_male_urban.json):  1117
# Number of transaction (young_adults_female_rural.json):  445
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  223
# Date 2021-07-15 00:00:00
# Number of customers newly onboard:  21
# Total customer:  1242
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  2776
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  434
# Number of transaction (adults_50up_female_rural.json):  756
# Number of transaction (adults_50up_female_urban.json):  0
# Number of transaction (adults_50up_male_rural.json):  1728
# Number of transaction (adults_50up_male_urban.json):  124
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  540
# Number of transaction (young_adults_male_urban.json):  433
# Date 2021-07-16 00:00:00
# Number of customers newly onboard:  17
# Total customer:  1259
# Number of transaction (adults_2550_female_rural.json):  1170
# Number of transaction (adults_2550_female_urban.json):  431
# Number of transaction (adults_2550_male_rural.json):  229
# Number of transaction (adults_2550_male_urban.json):  1491
# Number of transaction (adults_50up_female_rural.json):  430
# Number of transaction (adults_50up_female_urban.json):  124
# Number of transaction (adults_50up_male_rural.json):  227
# Number of transaction (adults_50up_male_urban.json):  114
# Number of transaction (young_adults_female_rural.json):  640
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  640
# Date 2021-07-17 00:00:00
# Number of customers newly onboard:  25
# Total customer:  1284
# Number of transaction (adults_2550_female_rural.json):  1576
# Number of transaction (adults_2550_female_urban.json):  309
# Number of transaction (adults_2550_male_rural.json):  646
# Number of transaction (adults_2550_male_urban.json):  1481
# Number of transaction (adults_50up_female_rural.json):  1486
# Number of transaction (adults_50up_female_urban.json):  243
# Number of transaction (adults_50up_male_rural.json):  1784
# Number of transaction (adults_50up_male_urban.json):  540
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-18 00:00:00
# Number of customers newly onboard:  26
# Total customer:  1310
# Number of transaction (adults_2550_female_rural.json):  1036
# Number of transaction (adults_2550_female_urban.json):  832
# Number of transaction (adults_2550_male_rural.json):  222
# Number of transaction (adults_2550_male_urban.json):  545
# Number of transaction (adults_50up_female_rural.json):  739
# Number of transaction (adults_50up_female_urban.json):  212
# Number of transaction (adults_50up_male_rural.json):  837
# Number of transaction (adults_50up_male_urban.json):  1058
# Number of transaction (young_adults_female_rural.json):  532
# Number of transaction (young_adults_female_urban.json):  516
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  223
# Date 2021-07-19 00:00:00
# Number of customers newly onboard:  14
# Total customer:  1324
# Number of transaction (adults_2550_female_rural.json):  512
# Number of transaction (adults_2550_female_urban.json):  0
# Number of transaction (adults_2550_male_rural.json):  110
# Number of transaction (adults_2550_male_urban.json):  928
# Number of transaction (adults_50up_female_rural.json):  530
# Number of transaction (adults_50up_female_urban.json):  534
# Number of transaction (adults_50up_male_rural.json):  623
# Number of transaction (adults_50up_male_urban.json):  7
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  316
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-20 00:00:00
# Number of customers newly onboard:  26
# Total customer:  1350
# Number of transaction (adults_2550_female_rural.json):  314
# Number of transaction (adults_2550_female_urban.json):  622
# Number of transaction (adults_2550_male_rural.json):  636
# Number of transaction (adults_2550_male_urban.json):  1758
# Number of transaction (adults_50up_female_rural.json):  1650
# Number of transaction (adults_50up_female_urban.json):  756
# Number of transaction (adults_50up_male_rural.json):  936
# Number of transaction (adults_50up_male_urban.json):  0
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  611
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-21 00:00:00
# Number of customers newly onboard:  20
# Total customer:  1370
# Number of transaction (adults_2550_female_rural.json):  2446
# Number of transaction (adults_2550_female_urban.json):  707
# Number of transaction (adults_2550_male_rural.json):  319
# Number of transaction (adults_2550_male_urban.json):  904
# Number of transaction (adults_50up_female_rural.json):  100
# Number of transaction (adults_50up_female_urban.json):  201
# Number of transaction (adults_50up_male_rural.json):  309
# Number of transaction (adults_50up_male_urban.json):  421
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  411
# Number of transaction (young_adults_male_rural.json):  17
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-22 00:00:00
# Number of customers newly onboard:  34
# Total customer:  1404
# Number of transaction (adults_2550_female_rural.json):  1003
# Number of transaction (adults_2550_female_urban.json):  1002
# Number of transaction (adults_2550_male_rural.json):  697
# Number of transaction (adults_2550_male_urban.json):  802
# Number of transaction (adults_50up_female_rural.json):  917
# Number of transaction (adults_50up_female_urban.json):  1645
# Number of transaction (adults_50up_male_rural.json):  1710
# Number of transaction (adults_50up_male_urban.json):  840
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  204
# Number of transaction (young_adults_male_rural.json):  605
# Number of transaction (young_adults_male_urban.json):  506
# Date 2021-07-23 00:00:00
# Number of customers newly onboard:  18
# Total customer:  1422
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  689
# Number of transaction (adults_2550_male_rural.json):  0
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  1494
# Number of transaction (adults_50up_female_urban.json):  932
# Number of transaction (adults_50up_male_rural.json):  109
# Number of transaction (adults_50up_male_urban.json):  402
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  208
# Date 2021-07-24 00:00:00
# Number of customers newly onboard:  31
# Total customer:  1453
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  1473
# Number of transaction (adults_2550_male_rural.json):  306
# Number of transaction (adults_2550_male_urban.json):  802
# Number of transaction (adults_50up_female_rural.json):  2584
# Number of transaction (adults_50up_female_urban.json):  605
# Number of transaction (adults_50up_male_rural.json):  106
# Number of transaction (adults_50up_male_urban.json):  722
# Number of transaction (young_adults_female_rural.json):  221
# Number of transaction (young_adults_female_urban.json):  204
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  387
# Date 2021-07-25 00:00:00
# Number of customers newly onboard:  38
# Total customer:  1491
# Number of transaction (adults_2550_female_rural.json):  1582
# Number of transaction (adults_2550_female_urban.json):  584
# Number of transaction (adults_2550_male_rural.json):  902
# Number of transaction (adults_2550_male_urban.json):  583
# Number of transaction (adults_50up_female_rural.json):  1801
# Number of transaction (adults_50up_female_urban.json):  820
# Number of transaction (adults_50up_male_rural.json):  795
# Number of transaction (adults_50up_male_urban.json):  503
# Number of transaction (young_adults_female_rural.json):  699
# Number of transaction (young_adults_female_urban.json):  207
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-26 00:00:00
# Number of customers newly onboard:  21
# Total customer:  1512
# Number of transaction (adults_2550_female_rural.json):  0
# Number of transaction (adults_2550_female_urban.json):  677
# Number of transaction (adults_2550_male_rural.json):  1087
# Number of transaction (adults_2550_male_urban.json):  581
# Number of transaction (adults_50up_female_rural.json):  511
# Number of transaction (adults_50up_female_urban.json):  405
# Number of transaction (adults_50up_male_rural.json):  102
# Number of transaction (adults_50up_male_urban.json):  398
# Number of transaction (young_adults_female_rural.json):  201
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  15
# Number of transaction (young_adults_male_urban.json):  484
# Date 2021-07-27 00:00:00
# Number of customers newly onboard:  29
# Total customer:  1541
# Number of transaction (adults_2550_female_rural.json):  483
# Number of transaction (adults_2550_female_urban.json):  1284
# Number of transaction (adults_2550_male_rural.json):  194
# Number of transaction (adults_2550_male_urban.json):  681
# Number of transaction (adults_50up_female_rural.json):  867
# Number of transaction (adults_50up_female_urban.json):  198
# Number of transaction (adults_50up_male_rural.json):  1284
# Number of transaction (adults_50up_male_urban.json):  502
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  205
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-28 00:00:00
# Number of customers newly onboard:  39
# Total customer:  1580
# Number of transaction (adults_2550_female_rural.json):  658
# Number of transaction (adults_2550_female_urban.json):  855
# Number of transaction (adults_2550_male_rural.json):  1735
# Number of transaction (adults_2550_male_urban.json):  772
# Number of transaction (adults_50up_female_rural.json):  860
# Number of transaction (adults_50up_female_urban.json):  301
# Number of transaction (adults_50up_male_rural.json):  794
# Number of transaction (adults_50up_male_urban.json):  299
# Number of transaction (young_adults_female_rural.json):  801
# Number of transaction (young_adults_female_urban.json):  862
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  563
# Date 2021-07-29 00:00:00
# Number of customers newly onboard:  44
# Total customer:  1624
# Number of transaction (adults_2550_female_rural.json):  1512
# Number of transaction (adults_2550_female_urban.json):  1484
# Number of transaction (adults_2550_male_rural.json):  1327
# Number of transaction (adults_2550_male_urban.json):  946
# Number of transaction (adults_50up_female_rural.json):  952
# Number of transaction (adults_50up_female_urban.json):  1818
# Number of transaction (adults_50up_male_rural.json):  295
# Number of transaction (adults_50up_male_urban.json):  862
# Number of transaction (young_adults_female_rural.json):  308
# Number of transaction (young_adults_female_urban.json):  935
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  562
# Date 2021-07-30 00:00:00
# Number of customers newly onboard:  18
# Total customer:  1642
# Number of transaction (adults_2550_female_rural.json):  1789
# Number of transaction (adults_2550_female_urban.json):  819
# Number of transaction (adults_2550_male_rural.json):  279
# Number of transaction (adults_2550_male_urban.json):  0
# Number of transaction (adults_50up_female_rural.json):  185
# Number of transaction (adults_50up_female_urban.json):  662
# Number of transaction (adults_50up_male_rural.json):  557
# Number of transaction (adults_50up_male_urban.json):  665
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  0
# Date 2021-07-31 00:00:00
# Number of customers newly onboard:  37
# Total customer:  1679
# Number of transaction (adults_2550_female_rural.json):  460
# Number of transaction (adults_2550_female_urban.json):  2307
# Number of transaction (adults_2550_male_rural.json):  469
# Number of transaction (adults_2550_male_urban.json):  1908
# Number of transaction (adults_50up_female_rural.json):  949
# Number of transaction (adults_50up_female_urban.json):  382
# ...
# Number of transaction (young_adults_male_urban.json):  89
# Date 2021-10-10 00:00:00
# Number of customers newly onboard:  179
# Total customer:  6818
# Number of transaction (adults_2550_female_rural.json):  1177
# Number of transaction (adults_2550_female_urban.json):  1511
# Number of transaction (adults_2550_male_rural.json):  966
# Number of transaction (adults_2550_male_urban.json):  1420
# Number of transaction (adults_50up_female_rural.json):  1216
# Number of transaction (adults_50up_female_urban.json):  935
# Number of transaction (adults_50up_male_rural.json):  781
# Number of transaction (adults_50up_male_urban.json):  788
# Number of transaction (young_adults_female_rural.json):  228
# Number of transaction (young_adults_female_urban.json):  312
# Number of transaction (young_adults_male_rural.json):  82
# Number of transaction (young_adults_male_urban.json):  131
# Date 2021-10-11 00:00:00
# Number of customers newly onboard:  98
# Total customer:  6916
# Number of transaction (adults_2550_female_rural.json):  612
# Number of transaction (adults_2550_female_urban.json):  683
# Number of transaction (adults_2550_male_rural.json):  460
# Number of transaction (adults_2550_male_urban.json):  496
# Number of transaction (adults_50up_female_rural.json):  866
# Number of transaction (adults_50up_female_urban.json):  494
# Number of transaction (adults_50up_male_rural.json):  411
# Number of transaction (adults_50up_male_urban.json):  314
# Number of transaction (young_adults_female_rural.json):  327
# Number of transaction (young_adults_female_urban.json):  41
# Number of transaction (young_adults_male_rural.json):  43
# Number of transaction (young_adults_male_urban.json):  396
# Date 2021-10-12 00:00:00
# Number of customers newly onboard:  78
# Total customer:  6994
# Number of transaction (adults_2550_female_rural.json):  466
# Number of transaction (adults_2550_female_urban.json):  400
# Number of transaction (adults_2550_male_rural.json):  526
# Number of transaction (adults_2550_male_urban.json):  605
# Number of transaction (adults_50up_female_rural.json):  516
# Number of transaction (adults_50up_female_urban.json):  491
# Number of transaction (adults_50up_male_rural.json):  432
# Number of transaction (adults_50up_male_urban.json):  139
# Number of transaction (young_adults_female_rural.json):  87
# Number of transaction (young_adults_female_urban.json):  77
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  285
# Date 2021-10-13 00:00:00
# Number of customers newly onboard:  145
# Total customer:  7139
# Number of transaction (adults_2550_female_rural.json):  647
# Number of transaction (adults_2550_female_urban.json):  1621
# Number of transaction (adults_2550_male_rural.json):  595
# Number of transaction (adults_2550_male_urban.json):  1021
# Number of transaction (adults_50up_female_rural.json):  891
# Number of transaction (adults_50up_female_urban.json):  865
# Number of transaction (adults_50up_male_rural.json):  331
# Number of transaction (adults_50up_male_urban.json):  462
# Number of transaction (young_adults_female_rural.json):  172
# Number of transaction (young_adults_female_urban.json):  63
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  284
# Date 2021-10-14 00:00:00
# Number of customers newly onboard:  125
# Total customer:  7264
# Number of transaction (adults_2550_female_rural.json):  693
# Number of transaction (adults_2550_female_urban.json):  477
# Number of transaction (adults_2550_male_rural.json):  647
# Number of transaction (adults_2550_male_urban.json):  761
# Number of transaction (adults_50up_female_rural.json):  690
# Number of transaction (adults_50up_female_urban.json):  466
# Number of transaction (adults_50up_male_rural.json):  593
# Number of transaction (adults_50up_male_urban.json):  505
# Number of transaction (young_adults_female_rural.json):  109
# Number of transaction (young_adults_female_urban.json):  71
# Number of transaction (young_adults_male_rural.json):  349
# Number of transaction (young_adults_male_urban.json):  272
# Date 2021-10-15 00:00:00
# Number of customers newly onboard:  112
# Total customer:  7376
# Number of transaction (adults_2550_female_rural.json):  676
# Number of transaction (adults_2550_female_urban.json):  903
# Number of transaction (adults_2550_male_rural.json):  740
# Number of transaction (adults_2550_male_urban.json):  563
# Number of transaction (adults_50up_female_rural.json):  514
# Number of transaction (adults_50up_female_urban.json):  594
# Number of transaction (adults_50up_male_rural.json):  192
# Number of transaction (adults_50up_male_urban.json):  444
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  123
# Number of transaction (young_adults_male_rural.json):  0
# Number of transaction (young_adults_male_urban.json):  106
# Date 2021-10-16 00:00:00
# Number of customers newly onboard:  170
# Total customer:  7546
# Number of transaction (adults_2550_female_rural.json):  960
# Number of transaction (adults_2550_female_urban.json):  1113
# Number of transaction (adults_2550_male_rural.json):  601
# Number of transaction (adults_2550_male_urban.json):  1287
# Number of transaction (adults_50up_female_rural.json):  1133
# Number of transaction (adults_50up_female_urban.json):  501
# Number of transaction (adults_50up_male_rural.json):  357
# Number of transaction (adults_50up_male_urban.json):  404
# Number of transaction (young_adults_female_rural.json):  155
# Number of transaction (young_adults_female_urban.json):  89
# Number of transaction (young_adults_male_rural.json):  349
# Number of transaction (young_adults_male_urban.json):  265
# Date 2021-10-17 00:00:00
# Number of customers newly onboard:  161
# Total customer:  7707
# Number of transaction (adults_2550_female_rural.json):  902
# Number of transaction (adults_2550_female_urban.json):  646
# Number of transaction (adults_2550_male_rural.json):  559
# Number of transaction (adults_2550_male_urban.json):  1175
# Number of transaction (adults_50up_female_rural.json):  571
# Number of transaction (adults_50up_female_urban.json):  900
# Number of transaction (adults_50up_male_rural.json):  615
# Number of transaction (adults_50up_male_urban.json):  703
# Number of transaction (young_adults_female_rural.json):  156
# Number of transaction (young_adults_female_urban.json):  171
# Number of transaction (young_adults_male_rural.json):  210
# Number of transaction (young_adults_male_urban.json):  142
# Date 2021-10-18 00:00:00
# Number of customers newly onboard:  88
# Total customer:  7795
# Number of transaction (adults_2550_female_rural.json):  446
# Number of transaction (adults_2550_female_urban.json):  432
# Number of transaction (adults_2550_male_rural.json):  361
# Number of transaction (adults_2550_male_urban.json):  345
# Number of transaction (adults_50up_female_rural.json):  397
# Number of transaction (adults_50up_female_urban.json):  151
# Number of transaction (adults_50up_male_rural.json):  509
# Number of transaction (adults_50up_male_urban.json):  139
# Number of transaction (young_adults_female_rural.json):  76
# Number of transaction (young_adults_female_urban.json):  0
# Number of transaction (young_adults_male_rural.json):  17
# Number of transaction (young_adults_male_urban.json):  99
# Date 2021-10-19 00:00:00
# Number of customers newly onboard:  138
# Total customer:  7933
# Number of transaction (adults_2550_female_rural.json):  594
# Number of transaction (adults_2550_female_urban.json):  859
# Number of transaction (adults_2550_male_rural.json):  493
# Number of transaction (adults_2550_male_urban.json):  464
# Number of transaction (adults_50up_female_rural.json):  281
# Number of transaction (adults_50up_female_urban.json):  600
# Number of transaction (adults_50up_male_rural.json):  426
# Number of transaction (adults_50up_male_urban.json):  525
# Number of transaction (young_adults_female_rural.json):  25
# Number of transaction (young_adults_female_urban.json):  58
# Number of transaction (young_adults_male_rural.json):  67
# Number of transaction (young_adults_male_urban.json):  189
# Date 2021-10-20 00:00:00
# Number of customers newly onboard:  135
# Total customer:  8068
# Number of transaction (adults_2550_female_rural.json):  569
# Number of transaction (adults_2550_female_urban.json):  584
# Number of transaction (adults_2550_male_rural.json):  365
# Number of transaction (adults_2550_male_urban.json):  658
# Number of transaction (adults_50up_female_rural.json):  715
# Number of transaction (adults_50up_female_urban.json):  388
# Number of transaction (adults_50up_male_rural.json):  299
# Number of transaction (adults_50up_male_urban.json):  322
# Number of transaction (young_adults_female_rural.json):  134
# Number of transaction (young_adults_female_urban.json):  116
# Number of transaction (young_adults_male_rural.json):  206
# Number of transaction (young_adults_male_urban.json):  10
# Date 2021-10-21 00:00:00
# Number of customers newly onboard:  176
# Total customer:  8244
# Number of transaction (adults_2550_female_rural.json):  662
# Number of transaction (adults_2550_female_urban.json):  911
# Number of transaction (adults_2550_male_rural.json):  421
# Number of transaction (adults_2550_male_urban.json):  556
# Number of transaction (adults_50up_female_rural.json):  362
# Number of transaction (adults_50up_female_urban.json):  434
# Number of transaction (adults_50up_male_rural.json):  639
# Number of transaction (adults_50up_male_urban.json):  251
# Number of transaction (young_adults_female_rural.json):  92
# Number of transaction (young_adults_female_urban.json):  258
# Number of transaction (young_adults_male_rural.json):  125
# Number of transaction (young_adults_male_urban.json):  83
# Date 2021-10-22 00:00:00
# Number of customers newly onboard:  152
# Total customer:  8396
# Number of transaction (adults_2550_female_rural.json):  485
# Number of transaction (adults_2550_female_urban.json):  402
# Number of transaction (adults_2550_male_rural.json):  278
# Number of transaction (adults_2550_male_urban.json):  637
# Number of transaction (adults_50up_female_rural.json):  557
# Number of transaction (adults_50up_female_urban.json):  292
# Number of transaction (adults_50up_male_rural.json):  510
# Number of transaction (adults_50up_male_urban.json):  347
# Number of transaction (young_adults_female_rural.json):  96
# Number of transaction (young_adults_female_urban.json):  59
# Number of transaction (young_adults_male_rural.json):  51
# Number of transaction (young_adults_male_urban.json):  47
# Date 2021-10-23 00:00:00
# Number of customers newly onboard:  175
# Total customer:  8571
# Number of transaction (adults_2550_female_rural.json):  390
# Number of transaction (adults_2550_female_urban.json):  682
# Number of transaction (adults_2550_male_rural.json):  537
# Number of transaction (adults_2550_male_urban.json):  709
# Number of transaction (adults_50up_female_rural.json):  274
# Number of transaction (adults_50up_female_urban.json):  317
# Number of transaction (adults_50up_male_rural.json):  281
# Number of transaction (adults_50up_male_urban.json):  271
# Number of transaction (young_adults_female_rural.json):  311
# Number of transaction (young_adults_female_urban.json):  99
# Number of transaction (young_adults_male_rural.json):  168
# Number of transaction (young_adults_male_urban.json):  161
# Date 2021-10-24 00:00:00
# Number of customers newly onboard:  110
# Total customer:  8681
# Number of transaction (adults_2550_female_rural.json):  282
# Number of transaction (adults_2550_female_urban.json):  337
# Number of transaction (adults_2550_male_rural.json):  239
# Number of transaction (adults_2550_male_urban.json):  284
# Number of transaction (adults_50up_female_rural.json):  355
# Number of transaction (adults_50up_female_urban.json):  213
# Number of transaction (adults_50up_male_rural.json):  286
# Number of transaction (adults_50up_male_urban.json):  282
# Number of transaction (young_adults_female_rural.json):  0
# Number of transaction (young_adults_female_urban.json):  29
# Number of transaction (young_adults_male_rural.json):  55
# Number of transaction (young_adults_male_urban.json):  41
# Date 2021-10-25 00:00:00
# Number of customers newly onboard:  151
# Total customer:  8832
# Number of transaction (adults_2550_female_rural.json):  482
# Number of transaction (adults_2550_female_urban.json):  312
# Number of transaction (adults_2550_male_rural.json):  366
# Number of transaction (adults_2550_male_urban.json):  243
# Number of transaction (adults_50up_female_rural.json):  410
# Number of transaction (adults_50up_female_urban.json):  346
# Number of transaction (adults_50up_male_rural.json):  205
# Number of transaction (adults_50up_male_urban.json):  194
# Number of transaction (young_adults_female_rural.json):  71
# Number of transaction (young_adults_female_urban.json):  149
# Number of transaction (young_adults_male_rural.json):  26
# Number of transaction (young_adults_male_urban.json):  164
# Date 2021-10-26 00:00:00
# Number of customers newly onboard:  106
# Total customer:  8938
# Number of transaction (adults_2550_female_rural.json):  219
# Number of transaction (adults_2550_female_urban.json):  247
# Number of transaction (adults_2550_male_rural.json):  221
# Number of transaction (adults_2550_male_urban.json):  156
# Number of transaction (adults_50up_female_rural.json):  157
# Number of transaction (adults_50up_female_urban.json):  148
# Number of transaction (adults_50up_male_rural.json):  186
# Number of transaction (adults_50up_male_urban.json):  155
# Number of transaction (young_adults_female_rural.json):  108
# Number of transaction (young_adults_female_urban.json):  35
# Number of transaction (young_adults_male_rural.json):  97
# Number of transaction (young_adults_male_urban.json):  77
# Date 2021-10-27 00:00:00
# Number of customers newly onboard:  107
# Total customer:  9045
# Number of transaction (adults_2550_female_rural.json):  172
# Number of transaction (adults_2550_female_urban.json):  137
# Number of transaction (adults_2550_male_rural.json):  159
# Number of transaction (adults_2550_male_urban.json):  132
# Number of transaction (adults_50up_female_rural.json):  195
# Number of transaction (adults_50up_female_urban.json):  177
# Number of transaction (adults_50up_male_rural.json):  173
# Number of transaction (adults_50up_male_urban.json):  175
# Number of transaction (young_adults_female_rural.json):  60
# Number of transaction (young_adults_female_urban.json):  28
# Number of transaction (young_adults_male_rural.json):  13
# Number of transaction (young_adults_male_urban.json):  39
# Date 2021-10-28 00:00:00
# Number of customers newly onboard:  91
# Total customer:  9136
# Number of transaction (adults_2550_female_rural.json):  91
# Number of transaction (adults_2550_female_urban.json):  139
# Number of transaction (adults_2550_male_rural.json):  91
# Number of transaction (adults_2550_male_urban.json):  132
# Number of transaction (adults_50up_female_rural.json):  126
# Number of transaction (adults_50up_female_urban.json):  152
# Number of transaction (adults_50up_male_rural.json):  98
# Number of transaction (adults_50up_male_urban.json):  140
# Number of transaction (young_adults_female_rural.json):  13
# Number of transaction (young_adults_female_urban.json):  11
# Number of transaction (young_adults_male_rural.json):  9
# Number of transaction (young_adults_male_urban.json):  48
# Date 2021-10-29 00:00:00
# Number of customers newly onboard:  217
# Total customer:  9353
# Number of transaction (adults_2550_female_rural.json):  319
# Number of transaction (adults_2550_female_urban.json):  234
# Number of transaction (adults_2550_male_rural.json):  268
# Number of transaction (adults_2550_male_urban.json):  264
# Number of transaction (adults_50up_female_rural.json):  255
# Number of transaction (adults_50up_female_urban.json):  196
# Number of transaction (adults_50up_male_rural.json):  195
# Number of transaction (adults_50up_male_urban.json):  398
# Number of transaction (young_adults_female_rural.json):  28
# Number of transaction (young_adults_female_urban.json):  97
# Number of transaction (young_adults_male_rural.json):  49
# Number of transaction (young_adults_male_urban.json):  90

# %%
print(f"Number of customers: {len(cust_list)}")
# Out:
# Number of customers: 9353
